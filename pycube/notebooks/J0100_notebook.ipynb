# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
#  # PSF Sub and Halo Finding

# %% [markdown]
# The code in this notebook is to test and showcase written functions for the python environment 'pycube'. It is designed to analyze MUSE data containers and the surrounding halo around QSOs and neighboring supermassive black holes.

# %% [markdown]
# ## Imports and data reading

# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import sep
from photutils import EllipticalAperture
import scipy as sp
from PIL import Image

import pycube
from pycube.core import background
from pycube.core import manip
from pycube import msgs
from pycube import core
from pycube import cubeClass
from pycube import psf
from pycube import halos
from pycube.instruments import vlt_muse
from IPython import embed
import math
import gc

# %% [markdown]
# There are three datasets that have been used for testing this program.

# %% [markdown]
# REQUIEM data without LYa halo

# %%
DATA_DIR = ('/home/ryan.foley/Downloads/J0100COPY.fits')

# %% [markdown]
# --------------------

# %% [markdown]
# Initializes the class object 'test_cube' and initializes the data table by calling 'from_fits_file'. In the future this function will have multiple specifications for the second parameter for different instruments.

# %%
test_cube = cubeClass.IfuCube(DATA_DIR, vlt_muse)

# %%
test_cube.initialize_file()

# %% [markdown]
# This program is written with the assumption those using it know the RA and DEC of their object of interest. To recieve the coordinates in pixel value call the function object_coord from the manip module with your cube object, RA, & DEC as arguments.

# %%
# for J0100
x_pos, y_pos = manip.object_coord(test_cube, 15.0543, 28.0405)

# %% [markdown]
# # Data Manipulation

# %% [markdown]
# The code is designed for users to specify how much of the container they want to analyze and on which axis they want to collapse upon. Given these are large data sets, analysis of a smaller section can be beneficial for hardware restraints.

# %% [markdown]
# ## Viewing Data

# %% [markdown]
# We can view the fits table which gives us the header descriptions of values and constants in the data as well as dimensions for our data container. For MUSE data we have a data set and 'stat' set, which is an equally sized variance cube of our data.

# %%
test_cube.hdul.info()
# Out:
# Filename: /home/ryan.foley/Downloads/J0100COPY.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU    1466   ()
#   1  DATA          1 ImageHDU        51   (326, 321, 1482)   float32
#   2  STAT          1 ImageHDU        43   (326, 321, 1482)   float32

# %% [markdown]
# The primary row contains just header information but is beneficial when working with this data. Below is the output.

# %%
test_cube.hdul[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                    8 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2019-02-15T16:23:57' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# ORIGIN  = 'ESO-PARANAL'        / European Southern Observatory
# TELESCOP= 'ESO-VLT-U4'         / ESO <TEL>
# INSTRUME= 'MUSE    '           / Instrument used.
# RA      =            15.053965 / [deg] 01:00:12.9 RA (J2000) pointing
# DEC     =             28.04023 / [deg] 28:02:24.8 DEC (J2000) pointing
# EQUINOX =                2000. / Standard FK5
# RADECSYS= 'FK5     '           / Coordinate system
# EXPTIME =                1482. / Integration time
# MJD-OBS =       58335.35936639 / Obs start
# DATE-OBS= '2018-08-05T08:37:29.000' / Observing date
# UTC     =               31037. / [s] 08:37:16.000 UTC
# LST     =             3064.063 / [s] 00:51:04.063 LST
# PI-COI  = 'UNKNOWN '           / PI-COI name.
# OBSERVER= 'UNKNOWN '           / Name of observer.
# PIPEFILE= 'DATACUBE_FINAL.fits' / Filename of data product
# BUNIT   = '10**(-20)*erg/s/cm**2/Angstrom'
# ARCFILE = 'MUSE.2018-08-05T08:37:29.256.fits' / Archive File Name
# DATAMD5 = 'f9b26bd6eeadf51fee533fc361ab0d46' / MD5 checksum
# OBJECT  = 'J0100p2802'         / Original target.
# HIERARCH ESO OBS AIRM =    1.7 / Req. max. airmass
# HIERARCH ESO OBS AMBI FWHM = 1.7 / Req. max. seeing
# HIERARCH ESO OBS AMBI TRANS = '3THN    ' / Req. sky transparency
# HIERARCH ESO OBS ATM = 'NATM    ' / Req. Atmospheric Turbulence Model
# HIERARCH ESO OBS CONTAINER ID = -999 / Scheduling container ID
# HIERARCH ESO OBS CONTAINER TYPE = 'U       ' / Scheduling container type
# HIERARCH ESO OBS CONTRAST = 0. / Req. contrast
# HIERARCH ESO OBS DID = 'ESO-VLT-DIC.OBS-2.0' / OBS Dictionary
# HIERARCH ESO OBS EXECTIME = 3599 / Expected execution time
# HIERARCH ESO OBS GRP = '0       ' / linked blocks
# HIERARCH ESO OBS ID =  1944536 / Observation block ID
# HIERARCH ESO OBS MOON DIST = 30 / Req. min. angular dist. from moon [deg]
# HIERARCH ESO OBS MOON FLI = 0.6 / Req. max. fractional lunar illum.
# HIERARCH ESO OBS NAME = 'WFM_J0100p2802' / OB name
# HIERARCH ESO OBS NTPL =      2 / Number of templates within OB
# HIERARCH ESO OBS OBSERVER = 'UNKNOWN ' / Observer Name
# HIERARCH ESO OBS PI-COI ID = 73422 / ESO internal PI-COI ID
# HIERARCH ESO OBS PI-COI NAME = 'UNKNOWN ' / PI-COI name
# HIERARCH ESO OBS PROG ID = '0101.A-0656(A)' / ESO program identification
# HIERARCH ESO OBS START = '2018-08-05T08:29:35' / OB start time
# HIERARCH ESO OBS STREHLRATIO = 0. / Req. strehl ratio
# HIERARCH ESO OBS TARG NAME = 'J0100p2802' / OB target name
# HIERARCH ESO OBS TPLNO =     2 / Template number within OB
# HIERARCH ESO OBS TWILIGHT =  0 / Req. twilight
# HIERARCH ESO OBS WATERVAPOUR = 0. / Req. water vapour
# HIERARCH ESO TPL DID = 'ESO-VLT-DIC.TPL-1.9' / Data dictionary for TPL
# HIERARCH ESO TPL EXPNO =     1 / Exposure number within template
# HIERARCH ESO TPL ID = 'MUSE_wfm-noao_obs_genericoffset' / Template signature ID
# HIERARCH ESO TPL NAME = 'Observation in WFM with user defined offsets' / Templat
# HIERARCH ESO TPL NEXP =      2 / Number of exposures within template
# HIERARCH ESO TPL PRESEQ = 'MUSE_obs_offset.seq' / Sequencer script
# HIERARCH ESO TPL START = '2018-08-05T08:36:28' / TPL start time
# HIERARCH ESO TPL VERSION = '$Revision: 297587 $' / Version of the template
# HIERARCH ESO TEL AG TYPE = 'FIELD_STAB' / Autoguiding type
# HIERARCH ESO TEL AIRM END = 1.655 / Airmass at end
# HIERARCH ESO TEL AIRM START = 1.652 / Airmass at start
# HIERARCH ESO TEL ALT =  37.193 / [deg] Alt angle at start
# HIERARCH ESO TEL AMBI FWHM END = 1.11 / [arcsec] Observatory Seeing queried from
# HIERARCH ESO TEL AMBI FWHM START = 1.01 / [arcsec] Observatory Seeing queried fr
# HIERARCH ESO TEL AMBI IRSKY TEMP = -92.7 / Temperature of the IR sky, from radio
# HIERARCH ESO TEL AMBI IWV END = 4.28 / Integrated Water Vapor
# HIERARCH ESO TEL AMBI IWV START = 4.41 / Integrated Water Vapor
# HIERARCH ESO TEL AMBI IWV30D END = 4.3 / IWV at 30deg elev.
# HIERARCH ESO TEL AMBI IWV30D START = 4.69 / IWV at 30deg elev.
# HIERARCH ESO TEL AMBI IWV30DSTD END = 0.04 / IWV at 30deg elev.
# HIERARCH ESO TEL AMBI IWV30DSTD START = 0.06 / IWV at 30deg elev.
# HIERARCH ESO TEL AMBI IWVSTD END = 0. / Standard Deviation of Integrated Water
# HIERARCH ESO TEL AMBI IWVSTD START = 0.03 / Standard Deviation of Integrated Wat
# HIERARCH ESO TEL AMBI PRES END = 743.15 / [hPa] Observatory ambient air pressure
# HIERARCH ESO TEL AMBI PRES START = 743.18 / [hPa] Observatory ambient air pressu
# HIERARCH ESO TEL AMBI RHUM = 21. / [%] Observatory ambient relative humidity qu
# HIERARCH ESO TEL AMBI TAU0 = 0.0022 / [s] Average coherence time
# HIERARCH ESO TEL AMBI TEMP = 7.99 / [deg C] Observatory ambient temperature quer
# HIERARCH ESO TEL AMBI WINDDIR = 113. / [deg] Observatory ambient wind direction
# HIERARCH ESO TEL AMBI WINDSP = 6.05 / [m/s] Observatory ambient wind speed queri
# HIERARCH ESO TEL AZ =  182.812 / [deg] Az angle at start S=0,W=90
# HIERARCH ESO TEL CHOP ST =   F / True when chopping is active
# HIERARCH ESO TEL DATE = '2000-01-01T00:00:00' / TCS installation date
# HIERARCH ESO TEL DID = 'ESO-VLT-DIC.TCS' / Data dictionary for TEL
# HIERARCH ESO TEL DOME STATUS = 'FULLY-OPEN' / Dome status
# HIERARCH ESO TEL FO POS =   0. / Adapter focus position during tracking
# HIERARCH ESO TEL FOCU ID = 'NB      ' / Telescope focus station ID
# HIERARCH ESO TEL FOCU LEN = 121.561 / [m] Focal length
# HIERARCH ESO TEL FOCU SCALE = 1.705 / [arcsec/mm] Focal scale
# HIERARCH ESO TEL FOCU VALUE = -18.857 / [mm] M2 setting
# HIERARCH ESO TEL GEOELEV = 2648. / [m] Elevation above sea level
# HIERARCH ESO TEL GEOLAT = -24.627 / [deg] Tel geo latitute (+=North)
# HIERARCH ESO TEL GEOLON = -70.404 / [deg] Tel geo longitude (+=East)
# HIERARCH ESO TEL IA FWHM = 1.29 / [arcsec] Delivered seeing corrected by airmass
# HIERARCH ESO TEL IA FWHMLIN = 1.42 / Delivered seeing on IA detector (linear fit
# HIERARCH ESO TEL IA FWHMLINOBS = 1.93 / Delivered seeing on IA detector (linear
# HIERARCH ESO TEL ID = 'v 303197' / TCS version number
# HIERARCH ESO TEL MOON DEC = 13.43459 / [deg] 13:26:04.5 DEC (J2000)
# HIERARCH ESO TEL MOON RA = 49.835333 / [deg] 03:19:20.4 RA (J2000)
# HIERARCH ESO TEL OPER = 'I, Condor' / Telescope Operator
# HIERARCH ESO TEL PARANG END = 175.5 / [deg] Parallactic angle at end
# HIERARCH ESO TEL PARANG START = -177.106 / [deg] Parallactic angle at start
# HIERARCH ESO TEL ROT ALTAZTRACK = T / Track rotator on alt/az instead of Alpha/D
# HIERARCH ESO TEL TARG ALPHA = 10013.027 / Alpha coordinate for the target
# HIERARCH ESO TEL TARG COORDTYPE = 'M       ' / Coordinate type (M=mean A=apparen
# HIERARCH ESO TEL TARG DELTA = 280225.84 / Delta coordinate for the target
# HIERARCH ESO TEL TARG EPOCH = 2000. / [yr] Epoch 1950 or 2000
# HIERARCH ESO TEL TARG EPOCHSYSTEM = 'J       ' / Epoch system (J=Julian / B=Bess
# HIERARCH ESO TEL TARG EQUINOX = 2000. / [yr] Equinox
# HIERARCH ESO TEL TARG PARALLAX = 0. / [arcsec] Parallax
# HIERARCH ESO TEL TARG PMA = 0. / [arcsec/yr] Proper Motion Alpha
# HIERARCH ESO TEL TARG PMD = 0. / [arcsec/yr] Proper motion Delta
# HIERARCH ESO TEL TARG RADVEL = 0. / [km/s] Radial velocity
# HIERARCH ESO TEL TH M1 TEMP = 7. / [deg C] M1 superficial temperature
# HIERARCH ESO TEL TRAK STATUS = 'NORMAL  ' / Tracking status
# HIERARCH ESO INS ADC1 DEC = 280814.55295 / [deg] Telescope declination
# HIERARCH ESO INS ADC1 ENC END = 190673 / [Enc] ADC encoder position at end
# HIERARCH ESO INS ADC1 ENC START = 190673 / [Enc] ADC encoder position at start
# HIERARCH ESO INS ADC1 END = -89.9999 / [deg] ADC position angle at end
# HIERARCH ESO INS ADC1 MODE = 'OFF     ' / ADC mode
# HIERARCH ESO INS ADC1 RA = 10113.533972 / [deg] Telescope right ascension
# HIERARCH ESO INS ADC2 DEC = 280814.55295 / [deg] Telescope declination
# HIERARCH ESO INS ADC2 ENC END = 230673 / [Enc] ADC encoder position at end
# HIERARCH ESO INS ADC2 ENC START = 230673 / [Enc] ADC encoder position at start
# HIERARCH ESO INS ADC2 END = -270. / [deg] ADC position angle at end
# HIERARCH ESO INS ADC2 MODE = 'OFF     ' / ADC mode
# HIERARCH ESO INS ADC2 RA = 10113.533972 / [deg] Telescope right ascension
# HIERARCH ESO INS AMPL1 ID = 'ampl1   ' / Pico-amplifier ID
# HIERARCH ESO INS AMPL1 SWSIM = F / If T, pico-amplifier software simulated
# HIERARCH ESO INS AMPL2 FILTER = 'Kron_V  ' / Name of filter in front of PD2
# HIERARCH ESO INS AMPL2 ID = 'ampl2   ' / Pico-amplifier ID
# HIERARCH ESO INS AMPL2 SWSIM = F / If T, pico-amplifier software simulated
# HIERARCH ESO INS AO DID1 = 'MUSF_ICS-310818' / Data dictionary for INS.
# HIERARCH ESO INS AO DID2 = 'PRIMARY-FITS-1.2' / Data dictionary for INS.
# HIERARCH ESO INS AO FILT1 ID = 'PS2     ' / Filter unique id.
# HIERARCH ESO INS AO FILT1 NAME = 'CLEAR   ' / Filter name.
# HIERARCH ESO INS AO FILT1 NO = 2 / Filter wheel position index.
# HIERARCH ESO INS AO FILT2 ID = '        ' / Filter unique id.
# HIERARCH ESO INS AO FILT2 NAME = '        ' / Filter name.
# HIERARCH ESO INS AO FILT2 NO = -1 / Filter wheel position index.
# HIERARCH ESO INS AO FILT3 ID = 'PS4     ' / Filter unique id.
# HIERARCH ESO INS AO FILT3 NAME = '1600_BW_90' / Filter name.
# HIERARCH ESO INS AO FILT3 NO = 4 / Filter wheel position index.
# HIERARCH ESO INS AO FOCU1 CONFIG = 'WFM     ' / Focus configuration.
# HIERARCH ESO INS AO FOCU1 DEC = -282152.8 / Telescope desclination [deg].
# HIERARCH ESO INS AO FOCU1 HNA = 87. / Sodium layer altitude [km].
# HIERARCH ESO INS AO FOCU1 LOOFFS = 1. / Low order offset [nm].
# HIERARCH ESO INS AO FOCU1 MODE = 'STAT    ' / Focus mode.
# HIERARCH ESO INS AO FOCU1 OFFSET = 0. / Position offset [mm].
# HIERARCH ESO INS AO FOCU1 POS = -0.1 / Position [mm].
# HIERARCH ESO INS AO FOCU1 RA = 175139.71 / Telescope right ascension [deg].
# HIERARCH ESO INS AO FOCU2 CONFIG = 'default ' / Focus configuration.
# HIERARCH ESO INS AO FOCU2 DEC = 0. / Telescope desclination [deg].
# HIERARCH ESO INS AO FOCU2 HNA = 90. / Sodium layer altitude [km].
# HIERARCH ESO INS AO FOCU2 LOOFFS = 0. / Low order offset [nm].
# HIERARCH ESO INS AO FOCU2 MODE = 'STAT    ' / Focus mode.
# HIERARCH ESO INS AO FOCU2 OFFSET = 0. / Position offset [mm].
# HIERARCH ESO INS AO FOCU2 POS = 0. / Position [mm].
# HIERARCH ESO INS AO FOCU2 RA = 0. / Telescope right ascension [deg].
# HIERARCH ESO INS AO ID = 'MUSF/176642' / Instrument ID.
# HIERARCH ESO INS AO MIRR1 ID = 'POS1    ' / Mirror unique ID.
# HIERARCH ESO INS AO MIRR1 NAME = 'WFM     ' / Mirror name.
# HIERARCH ESO INS AO MIRR1 NO = 1 / Mirror slide position.
# HIERARCH ESO INS AO MIRR2 ID = 'POS1    ' / Mirror unique ID.
# HIERARCH ESO INS AO MIRR2 NAME = 'WFM     ' / Mirror name.
# HIERARCH ESO INS AO MIRR2 NO = 1 / Mirror slide position.
# HIERARCH ESO INS AO MIRR3 ID = 'POS2    ' / Mirror unique ID.
# HIERARCH ESO INS AO MIRR3 NAME = 'OUT     ' / Mirror name.
# HIERARCH ESO INS AO MIRR3 NO = 2 / Mirror slide position.
# HIERARCH ESO INS AO MIRR4 ID = 'POS1    ' / Mirror unique ID.
# HIERARCH ESO INS AO MIRR4 NAME = '60mas   ' / Mirror name.
# HIERARCH ESO INS AO MIRR4 NO = 1 / Mirror slide position.
# HIERARCH ESO INS AO MODE = 'WFM     ' / AO MODE assembly.
# HIERARCH ESO INS AO OPTI2 ID = '        ' / OPTIi unique ID.
# HIERARCH ESO INS AO OPTI2 NAME = '        ' / OPTIi name.
# HIERARCH ESO INS AO OPTI2 NO = -1 / OPTIi slot number.
# HIERARCH ESO INS AO OPTI2 TYPE = '        ' / OPTIi element.
# HIERARCH ESO INS AO OPTI3 ID = 'OUT     ' / OPTIi unique ID.
# HIERARCH ESO INS AO OPTI3 NAME = 'OUT     ' / OPTIi name.
# HIERARCH ESO INS AO OPTI3 NO = 2 / OPTIi slot number.
# HIERARCH ESO INS AO OPTI3 TYPE = 'FILTER  ' / OPTIi element.
# HIERARCH ESO INS AO POS2 POS = 4958 / [enc] Position.
# HIERARCH ESO INS AO POS2 TEMP = 0. / Temperature used to adjust the position [d
# HIERARCH ESO INS AO POS3 POS = 14.8131 / [mm] Position.
# HIERARCH ESO INS AO POS3 TEMP = 0. / Temperature used to adjust the position [d
# HIERARCH ESO INS AO POS4 POS = 13.0677 / [mm] Position.
# HIERARCH ESO INS AO POS4 TEMP = 0. / Temperature used to adjust the position [d
# HIERARCH ESO INS AO POS5 POS = 10741 / [enc] Position.
# HIERARCH ESO INS AO POS5 TEMP = 0. / Temperature used to adjust the position [d
# HIERARCH ESO INS AO POS6 POS = 31264 / [enc] Position.
# HIERARCH ESO INS AO POS6 TEMP = 0. / Temperature used to adjust the position [d
# HIERARCH ESO INS AO ROT1 COLLNSYM = T / if T, non sym dist. correc. isactivated.
# HIERARCH ESO INS AO ROT1 COLLSYM = T / if T, sym. dist. correc.  is activated.
# HIERARCH ESO INS AO ROT1 CU = F / Enable CU distortions.
# HIERARCH ESO INS AO ROT1 DEC = -282152.8 / Telescope declination [ddmmss].
# HIERARCH ESO INS AO ROT1 INCS = 'EQUATORIAL' / Input coordinate system.
# HIERARCH ESO INS AO ROT1 MODE = 'STAT    ' / Instrument derotator mode.
# HIERARCH ESO INS AO ROT1 OFFSDEC = 2.52895 / DEC offset [arcsec].
# HIERARCH ESO INS AO ROT1 OFFSRA = -2.12205 / RA offset [arcsec].
# HIERARCH ESO INS AO ROT1 PMA = 0. / Proper motion in alpha [arcs].
# HIERARCH ESO INS AO ROT1 PMD = 0. / Proper motion in delta [arcs].
# HIERARCH ESO INS AO ROT1 POM = T / if T, pointing model is activated.
# HIERARCH ESO INS AO ROT1 RA = 175139.71 / Telescope right ascension [hhmmss]
# HIERARCH ESO INS AO ROT1 RADENC = 254127 / FS FSRAD absolute position.
# HIERARCH ESO INS AO ROT1 RHO = 41.5702 / FS GALACSI field radial value [mm].
# HIERARCH ESO INS AO ROT1 ROTENC = 485935 / FS FSROT absolute position.
# HIERARCH ESO INS AO ROT1 THETA = -110.141 / FS GALACSI field rot angle [deg].
# HIERARCH ESO INS AO ROT1 TTDEC = -282254.239 / TT star declination [ddmmss].
# HIERARCH ESO INS AO ROT1 TTRA = 175141.78 / TT star right ascension [hhmmss]
# HIERARCH ESO INS AO ROT1 WLEN = 700. / FS GALACSI wavelength [nm].
# HIERARCH ESO INS AO ROT1 X = -14.3138 / Position at NA focal plane [mm].
# HIERARCH ESO INS AO ROT1 Y = -39.0282 / Position at NA focal plane [mm].
# HIERARCH ESO INS AO SENS1 STAT10 = F / Warning WFS Peltier2.
# HIERARCH ESO INS AO SENS1 STAT11 = F / Warning WFS Peltier5.
# HIERARCH ESO INS AO SENS1 STAT12 = F / Warning WFS Peltier3.
# HIERARCH ESO INS AO SENS1 STAT2 = F / Alarm NA Cabinet Overtemp.
# HIERARCH ESO INS AO SENS1 STAT3 = F / Warning leak WFS TT-TCCD .
# HIERARCH ESO INS AO SENS1 STAT4 = F / Warning failure L2 supply.
# HIERARCH ESO INS AO SENS1 STAT5 = F / Warning leak WFS2-4.
# HIERARCH ESO INS AO SENS1 STAT6 = F / Warning failure L3 supply.
# HIERARCH ESO INS AO SENS1 STAT7 = F / Warning leak WFS1-3.
# HIERARCH ESO INS AO SENS1 STAT8 = F / Warning WFS Peltier1.
# HIERARCH ESO INS AO SENS1 STAT9 = F / Warning WFS Peltier4.
# HIERARCH ESO INS AO SENS1 VAL1 = 6.555 / Flow meter cooling.
# HIERARCH ESO INS AO SENS2 ID = 'detT    ' / sensor ID.
# HIERARCH ESO INS AO SENS2 NAME = 'IR Det Temp.' / sensor common name.
# HIERARCH ESO INS AO SENS2 VAL1 = 87.387 / [K] IR Det Temperature.
# HIERARCH ESO INS AO SENS3 STAT10 = F / Warm/Cold.
# HIERARCH ESO INS AO SENS3 STAT11 = F / Start SPT.
# HIERARCH ESO INS AO SENS3 STAT12 = F / CPL Flow OFF.
# HIERARCH ESO INS AO SENS3 STAT13 = F / EXG Heat OFF.
# HIERARCH ESO INS AO SENS3 VAL1 = 0. / Main Line Vacuum.
# HIERARCH ESO INS AO SENS3 VAL3 = 84.029 / Cold Plate.
# HIERARCH ESO INS AO SENS3 VAL4 = 275.098 / LN2 Exhaust Gas.
# HIERARCH ESO INS AO SENS3 VAL5 = 110.194 / Sorption Pump.
# HIERARCH ESO INS AO SENS3 VAL7 = 84. / Cold Plate Set Point.
# HIERARCH ESO INS AO SENS3 VAL8 = 275. / Exhaust Set Point.
# HIERARCH ESO INS AO SENS3 VAL9 = 0. / Sorption Set Point.
# HIERARCH ESO INS AO SENS4 STAT14 = F / LGS2 CCD overtemperature.
# HIERARCH ESO INS AO SENS4 STAT15 = F / LGS2 block overtemperature.
# HIERARCH ESO INS AO SENS4 STAT16 = F / LGS2 HW fault.
# HIERARCH ESO INS AO SENS4 STAT17 = F / LGS2 block failure.
# HIERARCH ESO INS AO SENS4 STAT18 = F / LGS2 cam1 or ext alarm.
# HIERARCH ESO INS AO SENS4 STAT23 = F / LGS3 CCD overtemperature.
# HIERARCH ESO INS AO SENS4 STAT24 = F / LGS3 block overtemperature.
# HIERARCH ESO INS AO SENS4 STAT25 = F / LGS3 HW fault.
# HIERARCH ESO INS AO SENS4 STAT26 = F / LGS3 block failure.
# HIERARCH ESO INS AO SENS4 STAT27 = F / LGS3 cam1 or ext alarm.
# HIERARCH ESO INS AO SENS4 STAT32 = F / LGS4 CCD overtemperature.
# HIERARCH ESO INS AO SENS4 STAT33 = F / LGS4 block overtemperature.
# HIERARCH ESO INS AO SENS4 STAT34 = F / LGS4 HW fault.
# HIERARCH ESO INS AO SENS4 STAT35 = F / LGS4 block failure.
# HIERARCH ESO INS AO SENS4 STAT36 = F / LGS4 cam1 or ext alarm.
# HIERARCH ESO INS AO SENS4 STAT41 = F / VITT CCD overtemperature.
# HIERARCH ESO INS AO SENS4 STAT42 = F / VITT block overtemperature.
# HIERARCH ESO INS AO SENS4 STAT43 = F / VITT HW fault.
# HIERARCH ESO INS AO SENS4 STAT44 = F / VITT block failure.
# HIERARCH ESO INS AO SENS4 STAT45 = F / VITT cam1 or ext alarm.
# HIERARCH ESO INS AO SENS4 STAT5 = F / LGS1 CCD overtemperature.
# HIERARCH ESO INS AO SENS4 STAT6 = F / LGS1 block overtemperature.
# HIERARCH ESO INS AO SENS4 STAT7 = F / LGS1 HW fault.
# HIERARCH ESO INS AO SENS4 STAT8 = F / LGS1 block failure.
# HIERARCH ESO INS AO SENS4 STAT9 = F / LGS1 cam1 or ext alarm.
# HIERARCH ESO INS AO SENS4 VAL1 = -40. / [C] LGS1 CCD temp set point.
# HIERARCH ESO INS AO SENS4 VAL10 = -40. / [C] LGS2 CCD temp set point.
# HIERARCH ESO INS AO SENS4 VAL11 = -40.002 / [C] LGS2 CCD temp value.
# HIERARCH ESO INS AO SENS4 VAL12 = 10.835 / [C] LGS2 block temperature.
# HIERARCH ESO INS AO SENS4 VAL13 = 46.45 / LGS2 output.
# HIERARCH ESO INS AO SENS4 VAL19 = -40. / [C] LGS3 CCD temp set point.
# HIERARCH ESO INS AO SENS4 VAL2 = -40.001 / [C] LGS1 CCD temp value.
# HIERARCH ESO INS AO SENS4 VAL20 = -40.006 / [C] LGS3 CCD temp value.
# HIERARCH ESO INS AO SENS4 VAL21 = 9.67 / [C] LGS3 block temperature.
# HIERARCH ESO INS AO SENS4 VAL22 = 45.628 / LGS3 output.
# HIERARCH ESO INS AO SENS4 VAL28 = -40. / [C] LGS4 CCD temp set point.
# HIERARCH ESO INS AO SENS4 VAL29 = -40.003 / [C] LGS4 CCD temp value.
# HIERARCH ESO INS AO SENS4 VAL3 = 10.572 / [C] LGS1 block temperature.
# HIERARCH ESO INS AO SENS4 VAL30 = 10.14 / [C] LGS4 block temperature.
# HIERARCH ESO INS AO SENS4 VAL31 = 49.572 / LGS4 output.
# HIERARCH ESO INS AO SENS4 VAL37 = -40. / [C] VITT CCD temp set point.
# HIERARCH ESO INS AO SENS4 VAL38 = -39.999 / [C] VITT CCD temp value.
# HIERARCH ESO INS AO SENS4 VAL39 = 10.449 / [C] VITT block temperature.
# HIERARCH ESO INS AO SENS4 VAL4 = 47.95 / LGS1 output.
# HIERARCH ESO INS AO SENS4 VAL40 = 45.088 / VITT output.
# HIERARCH ESO INS AO SENS5 STAT1 = F / Fan State.
# HIERARCH ESO INS AO SENS5 STAT2 = F / Valve.
# HIERARCH ESO INS AO SENS5 STAT3 = F / Cabinet Alarm.
# HIERARCH ESO INS AO SENS5 STAT4 = F / Door State.
# HIERARCH ESO INS AO SENS5 VAL10 = 9.4 / Inlet water.
# HIERARCH ESO INS AO SENS5 VAL11 = 10.2 / Outlet water.
# HIERARCH ESO INS AO SENS5 VAL12 = 0.8 / Water temperature difference.
# HIERARCH ESO INS AO SENS5 VAL5 = 11. / Cooled Air .
# HIERARCH ESO INS AO SENS5 VAL6 = 9.2 / Ambient Air.
# HIERARCH ESO INS AO SENS5 VAL7 = 14.8 / Warm Air.
# HIERARCH ESO INS AO SENS5 VAL8 = 5.6 / Temperature difference.
# HIERARCH ESO INS AO SENS5 VAL9 = 4.398 / Liquid flow.
# HIERARCH ESO INS AO SENS6 ID = 'CB4T    ' / sensor ID.
# HIERARCH ESO INS AO SENS6 NAME = 'Cabinet4 Temp' / sensor common name.
# HIERARCH ESO INS AO SENS6 VAL1 = 10.7 / Temperature Cabinet 1.
# HIERARCH ESO INS AO SENS6 VAL2 = 13.7 / Temperature Cabinet 2.
# HIERARCH ESO INS AO SENS7 STAT1 = 'CLOSED  ' / Sensor string value.
# HIERARCH ESO INS AO SENS7 VAL2 = 9999. / Sensor numeric value.
# HIERARCH ESO INS AO SENSOR1 ID = 'flm1    ' / Sensor device unique id.
# HIERARCH ESO INS AO SENSOR1 NAME = 'Flow sensor' / Sensor device common name.
# HIERARCH ESO INS AO SENSOR2 ID = 'irtmp   ' / Sensor device unique id.
# HIERARCH ESO INS AO SENSOR2 NAME = 'IR det controller' / Sensor device common na
# HIERARCH ESO INS AO SENSOR5 ID = 'pccc    ' / Sensor device unique id.
# HIERARCH ESO INS AO SENSOR5 NAME = 'PLC cooling controller' / Sensor device comm
# HIERARCH ESO INS AO SENSOR6 ID = 'asen1   ' / Sensor device unique id.
# HIERARCH ESO INS AO SENSOR6 NAME = 'Analog sen.' / Sensor device common name.
# HIERARCH ESO INS AO SENSOR7 ID = 'irv     ' / Sensor device unique id.
# HIERARCH ESO INS AO SENSOR7 NAME = 'PLC IR VCS' / Sensor device common name.
# HIERARCH ESO INS AO SENSOR7 SWSIM = T / If T, function is software simulated.
# HIERARCH ESO INS AO SHUT1 ID = 'ISHUT   ' / Shutter ID.
# HIERARCH ESO INS AO SHUT1 NAME = 'Instrument shutter' / Shutter name.
# HIERARCH ESO INS AO SHUT1 ST = T / Shutter open.
# HIERARCH ESO INS AO SHUT2 ID = 'PWRC    ' / Shutter ID.
# HIERARCH ESO INS AO SHUT2 NAME = 'PWR Control' / Shutter name.
# HIERARCH ESO INS AO SHUT2 STAT = 'On      ' / Device position.
# HIERARCH ESO INS AO SWSIM = 'NORMAL  ' / Software simulation.
# HIERARCH ESO INS DATE = '2000-06-16' / Instrument release date (yyyy-mm-dd).
# HIERARCH ESO INS DID1 = 'MUSE_ICS-307521' / Data dictionary for INSi
# HIERARCH ESO INS DID2 = 'PRIMARY-FITS-1.2' / Data dictionary for INSi
# HIERARCH ESO INS DROT DEC = 280814.55295 / [deg] Telescope declination
# HIERARCH ESO INS DROT ENC END = 44250262 / [Enc] Derotator encoder position at e
# HIERARCH ESO INS DROT ENC START = 42895240 / [Enc] Derotator encoder position at
# HIERARCH ESO INS DROT END = -241.297 / [deg] Derotator position angle at end
# HIERARCH ESO INS DROT MODE = 'SKY     ' / Instrument derotator mode
# HIERARCH ESO INS DROT POSANG = 90. / [deg] Derotator position angle
# HIERARCH ESO INS DROT RA = 10113.533972 / [deg] Telescope right ascension
# HIERARCH ESO INS ID = 'MUSE/176642' / Instrument ID
# HIERARCH ESO INS IFU1 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU1 CHAN = 2 / Integral Field Unit channel
# HIERARCH ESO INS IFU1 DV ID = '16      ' / Detector Vessel ID
# HIERARCH ESO INS IFU1 ID = '01      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU1 ISS ID = '24      ' / Image Slicer System ID
# HIERARCH ESO INS IFU1 PREAMP ID = '36      ' / Detector cable ID
# HIERARCH ESO INS IFU1 SPS ID = '01      ' / Spectograph System ID
# HIERARCH ESO INS IFU1 VPHG ID = '08      ' / Volume Phase Holographic Grating ID
# HIERARCH ESO INS IFU10 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU10 CHAN = 3 / Integral Field Unit channel
# HIERARCH ESO INS IFU10 DV ID = '25      ' / Detector Vessel ID
# HIERARCH ESO INS IFU10 ID = '10      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU10 ISS ID = '10      ' / Image Slicer System ID
# HIERARCH ESO INS IFU10 PREAMP ID = '29      ' / Detector cable ID
# HIERARCH ESO INS IFU10 SPS ID = '10      ' / Spectograph System ID
# HIERARCH ESO INS IFU10 VPHG ID = '19      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU11 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU11 CHAN = 12 / Integral Field Unit channel
# HIERARCH ESO INS IFU11 DV ID = '10      ' / Detector Vessel ID
# HIERARCH ESO INS IFU11 ID = '11      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU11 ISS ID = '03      ' / Image Slicer System ID
# HIERARCH ESO INS IFU11 PREAMP ID = '55      ' / Detector cable ID
# HIERARCH ESO INS IFU11 SPS ID = '11      ' / Spectograph System ID
# HIERARCH ESO INS IFU11 VPHG ID = '15      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU12 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU12 CHAN = 7 / Integral Field Unit channel
# HIERARCH ESO INS IFU12 DV ID = '21      ' / Detector Vessel ID
# HIERARCH ESO INS IFU12 ID = '12      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU12 ISS ID = '09      ' / Image Slicer System ID
# HIERARCH ESO INS IFU12 PREAMP ID = '50      ' / Detector cable ID
# HIERARCH ESO INS IFU12 SPS ID = '12      ' / Spectograph System ID
# HIERARCH ESO INS IFU12 VPHG ID = '21      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU13 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU13 CHAN = 21 / Integral Field Unit channel
# HIERARCH ESO INS IFU13 DV ID = '22      ' / Detector Vessel ID
# HIERARCH ESO INS IFU13 ID = '13      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU13 ISS ID = '08      ' / Image Slicer System ID
# HIERARCH ESO INS IFU13 PREAMP ID = '78      ' / Detector cable ID
# HIERARCH ESO INS IFU13 SPS ID = '13      ' / Spectograph System ID
# HIERARCH ESO INS IFU13 VPHG ID = '18      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU14 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU14 CHAN = 5 / Integral Field Unit channel
# HIERARCH ESO INS IFU14 DV ID = '23      ' / Detector Vessel ID
# HIERARCH ESO INS IFU14 ID = '14      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU14 ISS ID = '12      ' / Image Slicer System ID
# HIERARCH ESO INS IFU14 PREAMP ID = '34      ' / Detector cable ID
# HIERARCH ESO INS IFU14 SPS ID = '14      ' / Spectograph System ID
# HIERARCH ESO INS IFU14 VPHG ID = '20      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU15 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU15 CHAN = 15 / Integral Field Unit channel
# HIERARCH ESO INS IFU15 DV ID = '26      ' / Detector Vessel ID
# HIERARCH ESO INS IFU15 ID = '15      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU15 ISS ID = '15      ' / Image Slicer System ID
# HIERARCH ESO INS IFU15 PREAMP ID = '66      ' / Detector cable ID
# HIERARCH ESO INS IFU15 SPS ID = '15      ' / Spectograph System ID
# HIERARCH ESO INS IFU15 VPHG ID = '22      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU16 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU16 CHAN = 18 / Integral Field Unit channel
# HIERARCH ESO INS IFU16 DV ID = '27      ' / Detector Vessel ID
# HIERARCH ESO INS IFU16 ID = '16      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU16 ISS ID = '16      ' / Image Slicer System ID
# HIERARCH ESO INS IFU16 PREAMP ID = '57      ' / Detector cable ID
# HIERARCH ESO INS IFU16 SPS ID = '16      ' / Spectograph System ID
# HIERARCH ESO INS IFU16 VPHG ID = '17      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU17 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU17 CHAN = 13 / Integral Field Unit channel
# HIERARCH ESO INS IFU17 DV ID = '17      ' / Detector Vessel ID
# HIERARCH ESO INS IFU17 ID = '17      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU17 ISS ID = '13      ' / Image Slicer System ID
# HIERARCH ESO INS IFU17 PREAMP ID = '46      ' / Detector cable ID
# HIERARCH ESO INS IFU17 SPS ID = '17      ' / Spectograph System ID
# HIERARCH ESO INS IFU17 VPHG ID = '16      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU18 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU18 CHAN = 9 / Integral Field Unit channel
# HIERARCH ESO INS IFU18 DV ID = '08      ' / Detector Vessel ID
# HIERARCH ESO INS IFU18 ID = '18      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU18 ISS ID = '19      ' / Image Slicer System ID
# HIERARCH ESO INS IFU18 PREAMP ID = '43      ' / Detector cable ID
# HIERARCH ESO INS IFU18 SPS ID = '18      ' / Spectograph System ID
# HIERARCH ESO INS IFU18 VPHG ID = '26      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU19 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU19 CHAN = 14 / Integral Field Unit channel
# HIERARCH ESO INS IFU19 DV ID = '13      ' / Detector Vessel ID
# HIERARCH ESO INS IFU19 ID = '19      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU19 ISS ID = '18      ' / Image Slicer System ID
# HIERARCH ESO INS IFU19 PREAMP ID = '37      ' / Detector cable ID
# HIERARCH ESO INS IFU19 SPS ID = '19      ' / Spectograph System ID
# HIERARCH ESO INS IFU19 VPHG ID = '23      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU2 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU2 CHAN = 6 / Integral Field Unit channel
# HIERARCH ESO INS IFU2 DV ID = '24      ' / Detector Vessel ID
# HIERARCH ESO INS IFU2 ID = '02      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU2 ISS ID = '06      ' / Image Slicer System ID
# HIERARCH ESO INS IFU2 PREAMP ID = '52      ' / Detector cable ID
# HIERARCH ESO INS IFU2 SPS ID = '02      ' / Spectograph System ID
# HIERARCH ESO INS IFU2 VPHG ID = '03      ' / Volume Phase Holographic Grating ID
# HIERARCH ESO INS IFU20 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU20 CHAN = 10 / Integral Field Unit channel
# HIERARCH ESO INS IFU20 DV ID = '20      ' / Detector Vessel ID
# HIERARCH ESO INS IFU20 ID = '20      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU20 ISS ID = '20      ' / Image Slicer System ID
# HIERARCH ESO INS IFU20 PREAMP ID = '38      ' / Detector cable ID
# HIERARCH ESO INS IFU20 SPS ID = '20      ' / Spectograph System ID
# HIERARCH ESO INS IFU20 VPHG ID = '24      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU21 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU21 CHAN = 11 / Integral Field Unit channel
# HIERARCH ESO INS IFU21 DV ID = '15      ' / Detector Vessel ID
# HIERARCH ESO INS IFU21 ID = '21      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU21 ISS ID = '17      ' / Image Slicer System ID
# HIERARCH ESO INS IFU21 PREAMP ID = '23      ' / Detector cable ID
# HIERARCH ESO INS IFU21 SPS ID = '21      ' / Spectograph System ID
# HIERARCH ESO INS IFU21 VPHG ID = '27      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU22 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU22 CHAN = 24 / Integral Field Unit channel
# HIERARCH ESO INS IFU22 DV ID = '14      ' / Detector Vessel ID
# HIERARCH ESO INS IFU22 ID = '22      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU22 ISS ID = '22      ' / Image Slicer System ID
# HIERARCH ESO INS IFU22 PREAMP ID = '54      ' / Detector cable ID
# HIERARCH ESO INS IFU22 SPS ID = '22      ' / Spectograph System ID
# HIERARCH ESO INS IFU22 VPHG ID = '11      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU23 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU23 CHAN = 23 / Integral Field Unit channel
# HIERARCH ESO INS IFU23 DV ID = '18      ' / Detector Vessel ID
# HIERARCH ESO INS IFU23 ID = '23      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU23 ISS ID = '23      ' / Image Slicer System ID
# HIERARCH ESO INS IFU23 PREAMP ID = '60      ' / Detector cable ID
# HIERARCH ESO INS IFU23 SPS ID = '23      ' / Spectograph System ID
# HIERARCH ESO INS IFU23 VPHG ID = '31      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU24 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU24 CHAN = 1 / Integral Field Unit channel
# HIERARCH ESO INS IFU24 DV ID = '12      ' / Detector Vessel ID
# HIERARCH ESO INS IFU24 ID = '24      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU24 ISS ID = '02      ' / Image Slicer System ID
# HIERARCH ESO INS IFU24 PREAMP ID = '24      ' / Detector cable ID
# HIERARCH ESO INS IFU24 SPS ID = '24      ' / Spectograph System ID
# HIERARCH ESO INS IFU24 VPHG ID = '10      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU3 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU3 CHAN = 8 / Integral Field Unit channel
# HIERARCH ESO INS IFU3 DV ID = '11      ' / Detector Vessel ID
# HIERARCH ESO INS IFU3 ID = '03      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU3 ISS ID = '14      ' / Image Slicer System ID
# HIERARCH ESO INS IFU3 PREAMP ID = '33      ' / Detector cable ID
# HIERARCH ESO INS IFU3 SPS ID = '03      ' / Spectograph System ID
# HIERARCH ESO INS IFU3 VPHG ID = '14      ' / Volume Phase Holographic Grating ID
# HIERARCH ESO INS IFU4 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU4 CHAN = 4 / Integral Field Unit channel
# HIERARCH ESO INS IFU4 DV ID = '03      ' / Detector Vessel ID
# HIERARCH ESO INS IFU4 ID = '04      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU4 ISS ID = '05      ' / Image Slicer System ID
# HIERARCH ESO INS IFU4 PREAMP ID = '59      ' / Detector cable ID
# HIERARCH ESO INS IFU4 SPS ID = '04      ' / Spectograph System ID
# HIERARCH ESO INS IFU4 VPHG ID = '07      ' / Volume Phase Holographic Grating ID
# HIERARCH ESO INS IFU5 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU5 CHAN = 22 / Integral Field Unit channel
# HIERARCH ESO INS IFU5 DV ID = '09      ' / Detector Vessel ID
# HIERARCH ESO INS IFU5 ID = '05      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU5 ISS ID = '11      ' / Image Slicer System ID
# HIERARCH ESO INS IFU5 PREAMP ID = '77      ' / Detector cable ID
# HIERARCH ESO INS IFU5 SPS ID = '05      ' / Spectograph System ID
# HIERARCH ESO INS IFU5 VPHG ID = '04      ' / Volume Phase Holographic Grating ID
# HIERARCH ESO INS IFU6 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU6 CHAN = 20 / Integral Field Unit channel
# HIERARCH ESO INS IFU6 DV ID = '07      ' / Detector Vessel ID
# HIERARCH ESO INS IFU6 ID = '06      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU6 ISS ID = '01      ' / Image Slicer System ID
# HIERARCH ESO INS IFU6 PREAMP ID = '79      ' / Detector cable ID
# HIERARCH ESO INS IFU6 SPS ID = '06      ' / Spectograph System ID
# HIERARCH ESO INS IFU6 VPHG ID = '06      ' / Volume Phase Holographic Grating ID
# HIERARCH ESO INS IFU7 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU7 CHAN = 17 / Integral Field Unit channel
# HIERARCH ESO INS IFU7 DV ID = '05      ' / Detector Vessel ID
# HIERARCH ESO INS IFU7 ID = '07      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU7 ISS ID = '07      ' / Image Slicer System ID
# HIERARCH ESO INS IFU7 PREAMP ID = '63      ' / Detector cable ID
# HIERARCH ESO INS IFU7 SPS ID = '07      ' / Spectograph System ID
# HIERARCH ESO INS IFU7 VPHG ID = '13      ' / Volume Phase Holographic Grating ID
# HIERARCH ESO INS IFU8 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU8 CHAN = 16 / Integral Field Unit channel
# HIERARCH ESO INS IFU8 DV ID = '06      ' / Detector Vessel ID
# HIERARCH ESO INS IFU8 ID = '08      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU8 ISS ID = '04      ' / Image Slicer System ID
# HIERARCH ESO INS IFU8 PREAMP ID = '56      ' / Detector cable ID
# HIERARCH ESO INS IFU8 SPS ID = '08      ' / Spectograph System ID
# HIERARCH ESO INS IFU8 VPHG ID = '05      ' / Volume Phase Holographic Grating ID
# HIERARCH ESO INS IFU9 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU9 CHAN = 19 / Integral Field Unit channel
# HIERARCH ESO INS IFU9 DV ID = '19      ' / Detector Vessel ID
# HIERARCH ESO INS IFU9 ID = '09      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU9 ISS ID = '21      ' / Image Slicer System ID
# HIERARCH ESO INS IFU9 PREAMP ID = '47      ' / Detector cable ID
# HIERARCH ESO INS IFU9 SPS ID = '09      ' / Spectograph System ID
# HIERARCH ESO INS IFU9 VPHG ID = '32      ' / Volume Phase Holographic Grating ID
# HIERARCH ESO INS LAMPNUM =   6 / Number of lamps
# HIERARCH ESO INS MODE = 'WFM-NOAO-N' / Instrument mode used.
# HIERARCH ESO INS OPTI1 ID = '1       ' / Optical function unique ID
# HIERARCH ESO INS OPTI1 NAME = 'Blue    ' / Pupil Filter Wheel filter name
# HIERARCH ESO INS OPTI1 NO =  1 / Pupil Filter Wheel slot number
# HIERARCH ESO INS OPTI1 TYPE = 'FILTER  ' / Pupil Filter Wheel element type
# HIERARCH ESO INS OPTI2 ID = '2       ' / Optical function unique ID
# HIERARCH ESO INS OPTI2 NAME = 'WFM     ' / Mode Switching Unit field mode
# HIERARCH ESO INS OPTI2 NO =  2 / Mode Switching Unit position
# HIERARCH ESO INS OPTI2 TYPE = 'FILTER  ' / Optical function element
# HIERARCH ESO INS OPTI3 ID = '1       ' / Optical function unique ID
# HIERARCH ESO INS OPTI3 NAME = 'WFM     ' / Calibration Unit Pickup Mirror Status
# HIERARCH ESO INS OPTI3 NO =  1 / Calibration Pickup Element position
# HIERARCH ESO INS OPTI3 TYPE = 'FREE    ' / Calibration Pickup Element type
# HIERARCH ESO INS OPTI4 ID = '4       ' / Optical function unique ID
# HIERARCH ESO INS OPTI4 NAME = 'Clear   ' / CU Focal Plan mask Wheel mask name
# HIERARCH ESO INS OPTI4 NO =  4 / CU Focal Plan Mask Wheel slot number
# HIERARCH ESO INS OPTI4 TYPE = 'MASK    ' / Optical function element
# HIERARCH ESO INS PATH = '        ' / Optical path used.
# HIERARCH ESO INS POS1 ENC = 734003 / [Enc] Position function absolute position
# HIERARCH ESO INS POS1 POS = 12.8 / [mm] Focusing stage position
# HIERARCH ESO INS POS2 ENC = 706631 / [Enc] Position function absolute position
# HIERARCH ESO INS POS2 POS = 14.541 / [mm] Focal Mask Alignment X position
# HIERARCH ESO INS POS3 ENC = 672225 / [Enc] Position function absolute position
# HIERARCH ESO INS POS3 POS = 13.833 / [mm] Focal Mask Alignment Y Position
# HIERARCH ESO INS POS4 ENC = 675481 / [Enc] Position function absolute position
# HIERARCH ESO INS POS4 POS = 13.9 / [mm] Focal Mask Alignment Z Position
# HIERARCH ESO INS PRES1 ID = 'ERP1    ' / Pressure sensor ID
# HIERARCH ESO INS PRES1 NAME = 'Right Enclosure Diff Pressure' / Pressure sensor
# HIERARCH ESO INS PRES1 VAL = -3.47 / [mBar] Right enclosure diff. pressure
# HIERARCH ESO INS PRES13 VAL = 0. / [mBar] Pre-vacuum pump pressure
# HIERARCH ESO INS PRES2 ID = 'ELP1    ' / Pressure sensor ID
# HIERARCH ESO INS PRES2 NAME = 'Left Enclosure Diff Pressure' / Pressure sensor n
# HIERARCH ESO INS PRES2 VAL = -0.93 / [mBar] Left enclosure diff. pressure
# HIERARCH ESO INS PRES21 VAL = 5.1E-06 / [mBar] Detector 1 pressure
# HIERARCH ESO INS PRES23 VAL = 9.0E-06 / [mBar] Detector 3 pressure
# HIERARCH ESO INS PRES25 VAL = 3.7E-06 / [mBar] Detector 5 pressure
# HIERARCH ESO INS PRES27 VAL = 2.8E-07 / [mBar] Detector 7 pressure
# HIERARCH ESO INS PRES29 VAL = 9.6E-06 / [mBar] Detector 9 pressure
# HIERARCH ESO INS PRES31 VAL = 4.8E-06 / [mBar] Detector 11 pressure
# HIERARCH ESO INS PRES33 VAL = 6.0E-06 / [mBar] Detector 13 pressure
# HIERARCH ESO INS PRES35 VAL = 3.5E-06 / [mBar] Detector 15 pressure
# HIERARCH ESO INS PRES37 VAL = 4.0E-06 / [mBar] Detector 17 pressure
# HIERARCH ESO INS PRES39 VAL = 2.5E-06 / [mBar] Detector 19 pressure
# HIERARCH ESO INS PRES41 VAL = 3.7E-06 / [mBar] Detector 21 pressure
# HIERARCH ESO INS PRES43 VAL = 2.5E-06 / [mBar] Detector 23 pressure
# HIERARCH ESO INS PRES45 VAL = 4.5E-06 / [mBar] Detector 2 pressure
# HIERARCH ESO INS PRES47 VAL = 2.7E-06 / [mBar] Detector 4 pressure
# HIERARCH ESO INS PRES49 VAL = 4.8E-06 / [mBar] Detector 6 pressure
# HIERARCH ESO INS PRES51 VAL = 6.4E-06 / [mBar] Detector 8 pressure
# HIERARCH ESO INS PRES53 VAL = 4.4E-06 / [mBar] Detector 10 pressure
# HIERARCH ESO INS PRES55 VAL = 4.4E-06 / [mBar] Detector 12 pressure
# HIERARCH ESO INS PRES57 VAL = 3.8E-06 / [mBar] Detector 14 pressure
# HIERARCH ESO INS PRES59 VAL = 3.7E-06 / [mBar] Detector 16 pressure
# HIERARCH ESO INS PRES61 VAL = 3.8E-06 / [mBar] Detector 18 pressure
# HIERARCH ESO INS PRES63 VAL = 4.1E-06 / [mBar] Detector 20 pressure
# HIERARCH ESO INS PRES65 VAL = 8.8E-06 / [mBar] Detector 22 pressure
# HIERARCH ESO INS PRES67 VAL = 4.7E-06 / [mBar] Detector 24 pressure
# HIERARCH ESO INS SENS1 ID = 'CURL1   ' / Sensor ID
# HIERARCH ESO INS SENS1 NAME = 'INS LAMP1 Current' / Sensor common name
# HIERARCH ESO INS SENS1 VAL = 3 / [10-1 A] Lamp 1 current value
# HIERARCH ESO INS SENS10 ID = 'TTL3    ' / Sensor ID
# HIERARCH ESO INS SENS10 NAME = 'INS LAMP3 Total Time' / Sensor common name
# HIERARCH ESO INS SENS10 VAL = 6516. / [h] Lamp #3 total time
# HIERARCH ESO INS SENS11 ID = 'OVTL3   ' / Sensor ID
# HIERARCH ESO INS SENS11 NAME = 'INS LAMP3 Over Temp. Alarm' / Sensor common name
# HIERARCH ESO INS SENS11 VAL = F / Lamp #3 over temperature alarm
# HIERARCH ESO INS SENS12 ID = 'ALTL3   ' / Sensor ID
# HIERARCH ESO INS SENS12 NAME = 'INS LAMP3 Temp. Latched Alarm' / Sensor common n
# ...
# HIERARCH ESO PRO CATG = 'DATACUBE_FINAL' / Category of pipeline product frame
# HIERARCH ESO PRO TYPE = 'REDUCED ' / Product type
# HIERARCH ESO PRO TECH = 'IFU     ' / Observation technique
# HIERARCH ESO PRO SCIENCE =   T / Scientific product if T
# HIERARCH ESO PRO REC3 ID = 'muse_exp_combine' / Pipeline recipe (unique) identif
# HIERARCH ESO PRO REC3 DRS ID = 'cpl-7.1 ' / Data Reduction System identifier
# HIERARCH ESO PRO REC3 PIPE ID = 'muse/2.6' / Pipeline (unique) identifier
# HIERARCH ESO PRO REC3 RAW1 NAME = 'PIXTABLE_REDUCED_0001.fits' / File name of ra
# HIERARCH ESO PRO REC3 RAW1 CATG = 'PIXTABLE_REDUCED' / Category of raw frame
# HIERARCH ESO PRO REC3 RAW2 NAME = 'PIXTABLE_REDUCED_0001.fits' / File name of ra
# HIERARCH ESO PRO REC3 RAW2 CATG = 'PIXTABLE_REDUCED' / Category of raw frame
# HIERARCH ESO PRO DATANCOM =  2 / Number of combined frames
# HIERARCH ESO PRO REC3 CAL1 NAME = 'J0100p2802.OFFSET_LIST.fits' / File name of c
# HIERARCH ESO PRO REC3 CAL1 CATG = 'OFFSET_LIST' / Category of calibration frame
# HIERARCH ESO PRO REC3 CAL1 DATAMD5 = 'c5ae95dc98ac689ad100a0af5b6e2cfb' / MD5 si
# HIERARCH ESO PRO REC3 PARAM1 NAME = 'save    ' / Select output product(s) to sav
# HIERARCH ESO PRO REC3 PARAM1 VALUE = 'cube    ' / Default: 'cube'
# HIERARCH ESO PRO REC3 PARAM2 NAME = 'resample' / The resampling technique to use
# HIERARCH ESO PRO REC3 PARAM2 VALUE = 'drizzle ' / Default: 'drizzle'
# HIERARCH ESO PRO REC3 PARAM3 NAME = 'dx      ' / Horizontal step size for resamp
# HIERARCH ESO PRO REC3 PARAM3 VALUE = '0       ' / Default: 0
# HIERARCH ESO PRO REC3 PARAM4 NAME = 'dy      ' / Vertical step size for resampli
# HIERARCH ESO PRO REC3 PARAM4 VALUE = '0       ' / Default: 0
# HIERARCH ESO PRO REC3 PARAM5 NAME = 'dlambda ' / Wavelength step size (in Angstr
# HIERARCH ESO PRO REC3 PARAM5 VALUE = '0       ' / Default: 0
# HIERARCH ESO PRO REC3 PARAM6 NAME = 'crtype  ' / Type of statistics used for det
# HIERARCH ESO PRO REC3 PARAM6 VALUE = 'median  ' / Default: 'median'
# HIERARCH ESO PRO REC3 PARAM7 NAME = 'crsigma ' / Sigma rejection factor to use f
# HIERARCH ESO PRO REC3 PARAM7 VALUE = '10      ' / Default: 10
# HIERARCH ESO PRO REC3 PARAM8 NAME = 'rc      ' / Critical radius for the "renka"
# HIERARCH ESO PRO REC3 PARAM8 VALUE = '1.25    ' / Default: 1.25
# HIERARCH ESO PRO REC3 PARAM9 NAME = 'pixfrac ' / Pixel down-scaling factor for t
# HIERARCH ESO PRO REC3 PARAM9 VALUE = '0.6,0.6 ' / Default: '0.6,0.6'
# HIERARCH ESO PRO REC3 PARAM10 NAME = 'ld      ' / Number of adjacent pixels to t
# HIERARCH ESO PRO REC3 PARAM10 VALUE = '1       ' / Default: 1
# HIERARCH ESO PRO REC3 PARAM11 NAME = 'format  ' / Type of output file format, "C
# HIERARCH ESO PRO REC3 PARAM11 VALUE = 'Cube    ' / Default: 'Cube'
# HIERARCH ESO PRO REC3 PARAM12 NAME = 'weight  ' / Type of weighting scheme to us
# HIERARCH ESO PRO REC3 PARAM12 VALUE = 'exptime ' / Default: 'exptime'
# HIERARCH ESO PRO REC3 PARAM13 NAME = 'filter  ' / The filter name(s) to be used
# HIERARCH ESO PRO REC3 PARAM13 VALUE = 'white   ' / Default: 'white'
# HIERARCH ESO PRO REC3 PARAM14 NAME = 'lambdamin' / Cut off the data below this w
# HIERARCH ESO PRO REC3 PARAM14 VALUE = '7500    ' / Default: 4000
# HIERARCH ESO PRO REC3 PARAM15 NAME = 'lambdamax' / Cut off the data above this w
# HIERARCH ESO PRO REC3 PARAM15 VALUE = '10000   ' / Default: 10000
# HIERARCH ESO ADA ABSROT END = 7.887 / [deg] Abs rot angle at exp end
# HIERARCH ESO ADA ABSROT PPOS = 'POS     ' / sign of probe position
# HIERARCH ESO ADA ABSROT START = 7.80854 / [deg] Abs rot angle at exp start
# HIERARCH ESO ADA GUID DEC = 27.9457 / [deg] 27:56:44.5 Guide star DEC J2000
# HIERARCH ESO ADA GUID RA = 14.943563 / [deg] 00:59:46.4 Guide star RA J2000
# HIERARCH ESO ADA GUID STATUS = 'ON      ' / Status of autoguider
# HIERARCH ESO ADA POSANG = -312.10522 / [deg] Position angle at start
# HIERARCH ESO ADA POSANG END = 40.49947 / [deg] Position angle at exposure end
# HIERARCH ESO ADA PUPILPOS = 45.00119 / [deg] Pupil position angle at exposure st
# HIERARCH ESO AOS HO LOOP ST = F / High Order loop status
# HIERARCH ESO AOS HO LOOP SUBSTATE = 41 / High Order loop substate
# HIERARCH ESO AOS IR LOOP ST = F / IRLOS loop status
# HIERARCH ESO AOS IR LOOP SUBSTATE = 0 / IRLOS loop substate
# HIERARCH ESO AOS JIT LOOP ST = F / Jitter loop status
# HIERARCH ESO AOS JIT LOOP SUBSTATE = 41 / Jitter loop substate
# HIERARCH ESO AOS NGS ALPHA = 175141.78 / [hms] Alpha coordinate for the NGS
# HIERARCH ESO AOS NGS DELTA = -282254.239 / [dms] Delta coordinate for the NGS
# HIERARCH ESO AOS TT LOOP ST = F / Tip-tilt loop status
# HIERARCH ESO AOS TT LOOP SUBSTATE = 41 / Tip-tilt loop substate
# HIERARCH ESO OCS DET1 IMGNAME = 'MUSE_WFM-NOAO_OBS' / Data File Name.
# HIERARCH ESO OCS IPS PIXSCALE = 0.2 / [arcsec/pixel] Pixel scale
# HIERARCH ESO OCS SGS AG FWHMX AVG = 1.041 / [arcsec] AG FWHM X mean value
# HIERARCH ESO OCS SGS AG FWHMX MAX = 1.229 / [arcsec] AG FWHM X maximum value
# HIERARCH ESO OCS SGS AG FWHMX MED = 1.03 / [arcsec] AG FWHM X median value
# HIERARCH ESO OCS SGS AG FWHMX MIN = 0.911 / [arcsec] AG FWHM X minimum value
# HIERARCH ESO OCS SGS AG FWHMX RMS = 0.068 / [arcsec] AG FWHM X RMS value
# HIERARCH ESO OCS SGS AG FWHMY AVG = 1.006 / [arcsec] AG FWHM Y mean value
# HIERARCH ESO OCS SGS AG FWHMY MAX = 1.165 / [arcsec] AG FWHM Y maximum value
# HIERARCH ESO OCS SGS AG FWHMY MED = 1.004 / [arcsec] AG FWHM Y median value
# HIERARCH ESO OCS SGS AG FWHMY MIN = 0.89 / [arcsec] AG FWHM Y minimum value
# HIERARCH ESO OCS SGS AG FWHMY RMS = 0.051 / [arcsec] AG FWHM Y RMS value
# HIERARCH ESO OCS SGS ALGO NAME = 'CORRELATOR' / Centering method
# HIERARCH ESO OCS SGS ALGO WIN SCALE = 6. / Factor for window size
# HIERARCH ESO OCS SGS ALGO WIN SIZE = 60 / [pix] Window size
# HIERARCH ESO OCS SGS ASM GL900 AVG = 0.021 / ASM ground layer ratio @ 900m mean
# HIERARCH ESO OCS SGS ASM GL900 MAX = 0.078 / ASM ground layer ratio @ 900m maxim
# HIERARCH ESO OCS SGS ASM GL900 MED = 0.011 / ASM ground layer ratio @ 900m media
# HIERARCH ESO OCS SGS ASM GL900 MIN = 0. / ASM ground layer ratio @ 900m minim
# HIERARCH ESO OCS SGS ASM GL900 RMS = 0.021 / ASM ground layer ratio @ 900m RMS v
# HIERARCH ESO OCS SGS FLUX AVG = 0. / [ADU] SGS flux mean value
# HIERARCH ESO OCS SGS FLUX MAX = 0. / [ADU] SGS flux maximum value
# HIERARCH ESO OCS SGS FLUX MED = 0. / [ADU] SGS flux median value
# HIERARCH ESO OCS SGS FLUX MIN = 0. / [ADU] SGS flux minimum value
# HIERARCH ESO OCS SGS FLUX RMS = 0. / [ADU] SGS flux RMS value
# HIERARCH ESO OCS SGS FLUX RMSPRC = 0. / [%] SGS flux RMS percentage value
# HIERARCH ESO OCS SGS FWHM AVG = 0. / [arcsec] SGS FWHM mean value
# HIERARCH ESO OCS SGS FWHM MAX = 0. / [arcsec] SGS FWHM maximum value
# HIERARCH ESO OCS SGS FWHM MED = 0. / [arcsec] SGS FWHM median value
# HIERARCH ESO OCS SGS FWHM MIN = 0. / [arcsec] SGS FWHM minimum value
# HIERARCH ESO OCS SGS FWHM RMS = 0. / [arcsec] SGS FWHM RMS value
# HIERARCH ESO OCS SGS LOOP CLOSED PRCTG = 0. / SGS closed loop percentage
# HIERARCH ESO OCS SGS LOOP GAIN = 0.95 / SGS loop gain
# HIERARCH ESO OCS SGS LOOP MODE = 3 / SGS loop mode
# HIERARCH ESO OCS SGS LOOP MODENAME = 'FREE RUN' / SGS loop mode name
# HIERARCH ESO OCS SGS LOOP PERIOD = 42 / [s] SGS loop period
# HIERARCH ESO OCS SGS LOOP ST = T / SGS loop status
# HIERARCH ESO OCS SGS NOBJ =  0 / Nb of objects for slow-guiding
# HIERARCH ESO OCS SGS OBJ1 FLUX = 0. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ1 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ1 USED PRCTG = 0. / % of time SGS object #i has been us
# HIERARCH ESO OCS SGS OBJ1 X = 0. / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ1 Y = 0. / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ10 FLUX = 0. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ10 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ10 USED PRCTG = 0. / % of time SGS object #i has been u
# HIERARCH ESO OCS SGS OBJ10 X = 0. / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ10 Y = 0. / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ2 FLUX = 0. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ2 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ2 USED PRCTG = 0. / % of time SGS object #i has been us
# HIERARCH ESO OCS SGS OBJ2 X = 0. / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ2 Y = 0. / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ3 FLUX = 0. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ3 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ3 USED PRCTG = 0. / % of time SGS object #i has been us
# HIERARCH ESO OCS SGS OBJ3 X = 0. / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ3 Y = 0. / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ4 FLUX = 0. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ4 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ4 USED PRCTG = 0. / % of time SGS object #i has been us
# HIERARCH ESO OCS SGS OBJ4 X = 0. / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ4 Y = 0. / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ5 FLUX = 0. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ5 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ5 USED PRCTG = 0. / % of time SGS object #i has been us
# HIERARCH ESO OCS SGS OBJ5 X = 0. / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ5 Y = 0. / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ6 FLUX = 0. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ6 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ6 USED PRCTG = 0. / % of time SGS object #i has been us
# HIERARCH ESO OCS SGS OBJ6 X = 0. / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ6 Y = 0. / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ7 FLUX = 0. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ7 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ7 USED PRCTG = 0. / % of time SGS object #i has been us
# HIERARCH ESO OCS SGS OBJ7 X = 0. / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ7 Y = 0. / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ8 FLUX = 0. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ8 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ8 USED PRCTG = 0. / % of time SGS object #i has been us
# HIERARCH ESO OCS SGS OBJ8 X = 0. / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ8 Y = 0. / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ9 FLUX = 0. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ9 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ9 USED PRCTG = 0. / % of time SGS object #i has been us
# HIERARCH ESO OCS SGS OBJ9 X = 0. / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ9 Y = 0. / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OFFSET DECAVG = 0. / [arcsec] SGS delta offset mean valu
# HIERARCH ESO OCS SGS OFFSET DECMAX = 0. / [arcsec] SGS delta offset maximum v
# HIERARCH ESO OCS SGS OFFSET DECMED = 0. / [arcsec] SGS delta offset median va
# HIERARCH ESO OCS SGS OFFSET DECMIN = 0. / [arcsec] SGS delta offset minimum v
# HIERARCH ESO OCS SGS OFFSET DECRMS = 0. / [arcsec] SGS delta offset RMS value
# HIERARCH ESO OCS SGS OFFSET DECSUM = 0. / [arcsec] SGS cumulated delta offset
# HIERARCH ESO OCS SGS OFFSET ENABLED = T / SGS offsetting status
# HIERARCH ESO OCS SGS OFFSET RAAVG = 0. / [arcsec] SGS alpha offset mean value
# HIERARCH ESO OCS SGS OFFSET RAMAX = 0. / [arcsec] SGS alpha offset maximum va
# HIERARCH ESO OCS SGS OFFSET RAMED = 0. / [arcsec] SGS alpha offset median val
# HIERARCH ESO OCS SGS OFFSET RAMIN = 0. / [arcsec] SGS alpha offset minimum va
# HIERARCH ESO OCS SGS OFFSET RARMS = 0. / [arcsec] SGS alpha offset RMS value
# HIERARCH ESO OCS SGS OFFSET RASUM = 0. / [arcsec] SGS cumulated alpha offset
# HIERARCH ESO OCS SGS OFFSET THRMAX = 1. / [arcsec] Alpha/Delta max offset thr
# HIERARCH ESO OCS SGS OFFSET THRMIN = 0.02 / [arcsec] Alpha/Delta min offset thr
# HIERARCH ESO OCS SGS PIXSCALE X = 0.093 / [arcsec/pix] X pixel scale of SGS
# HIERARCH ESO OCS SGS PIXSCALE Y = 0.0895 / [arcsec/pix] Y pixel scale of SGS
# HIERARCH ESO OCS SGS REF NBIMG = 1 / Number of images for reference image
# HIERARCH ESO OCS SGS REF SAVE = 'MUSE_SGS_REF_START_POS.fits' / SGS reference fi
# HIERARCH ESO OCS SGS REF ST = T / SGS reference image acquisition
# HIERARCH ESO OCS SGS REJECT PRCTG = 0. / Image rejection ratio
# HIERARCH ESO OCS TEL ACCESS = 'NORMAL  ' / Sub-system access mode.
# HIERARCH ESO SEQ OFFSET COORDS = 'SKY     ' / Offset coordinate type
# HIERARCH ESO SEQ OFFSET CUM ALPHA = -1. / [arcsec] Cumulative alpha offset
# HIERARCH ESO SEQ OFFSET CUM DELTA = -1. / [arcsec] Cumulative delta offset
# HIERARCH ESO SEQ OFFSET REL ALPHA = -1. / [arcsec] Relative alpha offset
# HIERARCH ESO SEQ OFFSET REL DELTA = -1. / [arcsec] Relative delta offset
# HIERARCH ESO QC EXPCOMB LAMBDA = 8426.25 / [Angstrom] Wavelength of plane in com
# HIERARCH ESO QC EXPCOMB NDET = 0 / Number of detected sources in combined cube.
# HIERARCH ESO QC EXPCOMB POS0 X = -1. / [pix] Position of source k in x-direction
# HIERARCH ESO QC EXPCOMB POS0 Y = -1. / [pix] Position of source k in y-direction
# HIERARCH ESO QC EXPCOMB FWHM0 X = -1. / [arcsec] FWHM of source k in x-direction
# HIERARCH ESO QC EXPCOMB FWHM0 Y = -1. / [arcsec] FWHM of source k in y-direction
# HIERARCH ESO DRS MUSE OFFSET1 DRA = 0. / [deg] (= 0.000000 arcsec) RA offset app
# HIERARCH ESO DRS MUSE OFFSET1 DDEC = 0. / [deg] (= 0.000000 arcsec) DEC offset a
# HIERARCH ESO DRS MUSE FLUX SCALE1 = 1.00001247319145 / flux scale factor applied
# HIERARCH ESO DRS MUSE OFFSET1 DATE-OBS = '2018-08-05T08:37:29.000' / offset 1 ap
# HIERARCH ESO DRS MUSE OFFSET2 DRA = -7.19983852528472E-05 / [deg] (= -0.259194 a
# HIERARCH ESO DRS MUSE OFFSET2 DDEC = -4.22374135400361E-05 / [deg] (= -0.152055
# HIERARCH ESO DRS MUSE FLUX SCALE2 = 1.09347633063036 / flux scale factor applied
# HIERARCH ESO DRS MUSE OFFSET2 DATE-OBS = '2018-08-05T09:04:10.000' / offset 2 ap
# HIERARCH ESO DRS MUSE FLUX FFCORR = T / Data was flat-field spectrum corrected
# CHECKSUM= 'UApga5oZUAoda3oZ'   / HDU checksum updated 2019-02-21T09:09:40
# DATASUM = '0       '           / data unit checksum updated 2019-02-21T09:09:40
# FLUXSCAL= '1.150145888'
# EBV     = '0.02767329970592872'

# %% [markdown]
# ## Cube Collapsing

# %% [markdown]
# Here we can collapse along a range of wavelength values, which is our z-axis, to produce a flattened section of the cube. Below are operations to collapse the first 300 wavelengths and display the 2D image.

# %%
collapsed_300D, collapsed_300S = manip.collapse_container(test_cube, 0, 300)

# %%
np.shape(collapsed_300D)
# Out:
# (321, 326)

# %%
plt.imshow(collapsed_300D, origin = 'lower')
plt.colorbar()

# %% [markdown]
# Alternatively, we could not specify a range and the function will collapse the entire container.

# %%
collapsed_fullD, collapsed_fullS = manip.collapse_container(test_cube)
# Out:
# collapse_container: Exceeded / unspecified wavelength in data cube. Max value is set to 1482
# collapse_container: Invalid / unspecified minimum wavelength. Min value is set to 0

# %%
np.shape(collapsed_fullD)
# Out:
# (321, 326)

# %%
plt.imshow(collapsed_fullD, origin = 'lower')
plt.colorbar()

gc.collect()
# Out:
# 35

# %% [markdown]
# ## De-reddening

# %% [markdown]
# There is an added function to correct for de-reddening of the data from cosmic dust. This function converts the entire data container which can then be re-collapsed and analyzed. Our code currently uses the extinction package with a model of Fitzpatrick & Massa (2007)

# %%
deRed_fullD, deRed_fullS = manip.dust_correction(test_cube)

# %%
deRed_collapse = manip.collapse_cube(deRed_fullD)
# Out:
# collapse_cube : Exceeded / unspecified wavelength in data cube. Max value is set to 1482
# collapse_cube : Invalid / unspecified minimum wavelength. Min value is set to 0

# %%
np.shape(deRed_collapse)
# Out:
# (321, 326)

# %%
plt.imshow(deRed_collapse, origin='lower')
plt.colorbar()

gc.collect()
# Out:
# 5696

# %% [markdown]
# # Background and Sources

# %% [markdown]
# ## Background Sub

# %% [markdown]
# First we want to remove any residual sources in the background.

# %% [markdown]
# subtract_bg is a function which utilizes SEP to smooth the background after isolating the sources. SEP is a re-creation of SourceXtractor for Python. These functions and beyond have parameters that must be tuned for each data set. We read in our object for some functions, where as others require output from earlier functions.

# %%
dataBg, statBg,_,_,_,_,_,_ = psf.subtract_bg(test_cube,
                                             sig_source_detect = 0.02,
                                             min_source_area=1.,
                                             source_mask_size=7.,
                                             edges=60,
                                             output=DATA_DIR,
                                             debug=True,
                                             show_debug=True,
                                             sigma_clipping=False)
gc.collect()
gc.collect()
# Out:
# subtract_bg: Starting the procedure to subtract the background
# stat_bg: Starting estimate of b/g stats
# collapse_cube : Exceeded / unspecified wavelength in data cube. Max value is set to 1482
# collapse_cube : Invalid / unspecified minimum wavelength. Min value is set to 0
# stat_bg: Searching for sources in the collapsed cube
# collapse_container: Exceeded / unspecified wavelength in data cube. Max value is set to 1482
# collapse_container: Invalid / unspecified minimum wavelength. Min value is set to 0
# stat_bg: Detected 29 sources
# stat_bg: Masking Edges
# stat_bg: Masking sources
# stat_bg: Performing b/g statistic
# stat_bg: Saving debug image on /home/ryan.foley/Downloads/J0100COPY.fits_BgRegion.pdf
# subtract_bg: Subtracting background from datacube
# subtract_bg: Estimating correction for statcube variance
# subtract_bg: The average correction factor for variance is 1.00696
# nice_plot: Setting rcParams
# subtract_bg: The average value subtracted to the b/g level is 0.08924
# nice_plot: Setting rcParams
# 0

# %%
averageBg, medianBg, stdBg, varBg, pixelsBg, maskBg2D = psf.stat_bg(test_cube,
                                                                    sig_source_detect=0.02,
                                                                    min_source_area=1.,
                                                                    source_mask_size=7.,
                                                                    edges=60,
                                                                    output=DATA_DIR,
                                                                    debug=True,
                                                                    show_debug=True)
gc.collect()
gc.collect()
# Out:
# stat_bg: Starting estimate of b/g stats
# collapse_cube : Exceeded / unspecified wavelength in data cube. Max value is set to 1482
# collapse_cube : Invalid / unspecified minimum wavelength. Min value is set to 0
# stat_bg: Searching for sources in the collapsed cube
# collapse_container: Exceeded / unspecified wavelength in data cube. Max value is set to 1482
# collapse_container: Invalid / unspecified minimum wavelength. Min value is set to 0
# stat_bg: Detected 29 sources
# stat_bg: Masking Edges
# stat_bg: Masking sources
# stat_bg: Performing b/g statistic
# stat_bg: Saving debug image on /home/ryan.foley/Downloads/J0100COPY.fits_BgRegion.pdf
# 0

# %% [markdown]
# ## Writing to File

# %% [markdown]
# Here we have a function which performs the above tasks of background isolation and source masking. It iterates through the entire cube, and writes the background and masks to the file. These code blocks are not active but are here to represent the availability of this function with the package.

# %% [raw]
# test_cube.get_background()

# %% [raw]
# test_cube.hdul.writeto('writetotest.fits',output_verify = 'silentfix', overwrite = True,checksum = True)

# %% [raw]
# test_cube.hdul.info()

# %% [markdown]
# Below it shows the now updated .fits with added rows for 'MASK' and 'BACKGROUND'.

# %% [markdown]
# We can showcase an example of the new sections by slicing a single wavelength and plotting the image.

# %% [raw]
# plt.imshow(test_cube.hdul[4].data[120,:,:], origin = 'lower')
# plt.title('Example of BACKGROUND',size = 18)
# plt.colorbar()

# %% [raw]
# plt.imshow(test_cube.hdul[3].data[120,:,:], origin = 'lower')
# plt.title('Example of MASK', size = 18)
# plt.colorbar()

# %% [markdown]
# # Wavelengths

# %% [markdown]
# ## Atmosphere

# %% [markdown]
# We can also convert our channel values into wave lengths using the 'convert_to_wave' function from the manip module.
# This function is utilized in other functions as well, but it stands on it's own for usability.

# %%
wavearray = manip.convert_to_wave(test_cube,test_cube.get_data())

# %% [markdown]
# Ploting the subtracted background average, median and sigma with the wave lengths yields the plot below. Notice that sigma is our atmospheric background.

# %%
plt.figure(0, figsize=(16,6))
plt.plot(wavearray, averageBg, alpha=0.7, color='dodgerblue', label='b/g average')
plt.plot(wavearray, stdBg, alpha=0.7, color='grey', label='b/g $\sigma$')
plt.plot(wavearray, medianBg, alpha=0.7, color='crimson', label='b/g median')
plt.xlabel(r'Wavelength [$\AA$]')
plt.ylabel(r'Flux [10$^{-17}$erg/s/cm$^2$/$\AA$]')
plt.title("Atmospheric Spectra J0100")
plt.legend(prop={"size": 15})

# %% [markdown]
# ## Quasar Spectrum

# %% [markdown]
# Using the function 'q_spectrum' from the manip module, we can extract the spectra from the object of interest. This function assumes the RA and DEC of the object have been converted to pixel values.

# %%
fluxQso, errQso, bgQso = manip.q_spectrum(test_cube,x_pos,y_pos)

# %% [markdown]
# We can plot the the data wavelengths against this flux

# %%
plt.figure(0, figsize=(16,6))
plt.plot(wavearray,fluxQso, alpha = 0.7, color = 'grey', label = "Flux")
plt.plot(wavearray,errQso,alpha = 0.7, color = 'dodgerblue', label = "$\sigma$")
plt.plot(wavearray,bgQso,alpha = 0.7, color = 'crimson', label = "Bg")
plt.xlabel(r'Wavelength [$\AA$]')
plt.ylabel(r'Flux [10$^{-17}$erg/s/cm$^2$/$\AA$]')
plt.title("Object Spectra J0100")
plt.legend(prop={'size': 15})
gc.collect()
# Out:
# 25

# %% [markdown]
# ------------------

# %% [markdown]
# Another helpful function is to call .get_dimensions on the IFUcube object to quickly get its value ranges. Specifically, this is helpful to see the channel ranges of the previous plot.

# %%
z_max, y_max, x_max = test_cube.get_dimensions()
channelarray = np.arange(0,z_max, 1)

# %%
plt.figure(0, figsize=(16,6))
plt.plot(channelarray,fluxQso, alpha = 0.7, color = 'grey', label = "Flux")
plt.plot(channelarray,errQso,alpha = 0.7, color = 'dodgerblue', label = "$\sigma$")
plt.plot(channelarray,bgQso,alpha = 0.7, color = 'crimson', label = "Bg")
plt.xlabel(r'Channel # (z)')
plt.ylabel(r'Flux [10$^{-17}$erg/s/cm$^2$/$\AA$]')
plt.title("Object Spectra J0100")
plt.legend(prop={'size': 15})

gc.collect()
# Out:
# 56028

# %% [markdown]
#  From this plot, we can easily visualize the channel values where we need to cut off / shrink the cube to perform the following functions in the package.

# %% [markdown]
#  ----------------

# %% [markdown]
# # Point Spread Function

# %% [markdown]
# The following code impliments a point-spread function to remove the highly luminous QSO (or other source) to isolate the potential surround halo.

# %% [markdown]
# ## PSF Creation

# %% [markdown]
# The first step is to normalize the flux produced by the QSO. using c_type=sum does just this. We also need to perform this function along the continuum just beyond were we estimate our LYa emission to be.

# %%
psf_data, psf_stat = psf.create_psf(dataBg,statcube=statBg,x_pos=x_pos,y_pos=y_pos,
                                  inner_rad=25,outer_rad=35,
                                  min_lambda=1130,max_lambda=1160,
                                  debug=True,show_debug=True, c_type='sum')
gc.collect()
gc.collect()
# Out:
# create_psf: Creating PSF model
# create_psf: Summing channels
# quick_ap_photometry: Performing aperture photometry
# Source 1 : Aperture photometry on source at: 168.16000000001364, 159.22000000000682
# create_psf: Removing local background of [9.42878246]
# create_psf: Normalizing central region to 1
#          (i.e. correcting for a factor [76028.06216227]
# create_psf: Creating circular mask around the position 168.16000000001364, 159.22000000000682
# location: single source identified
# create_psf: Creating debug images
# nice_plot: Setting rcParams
# 0

# %% [markdown]
# -------------

# %% [markdown]
# ## PSF Cleaning

# %% [markdown]
# The function 'clean_psf' from the fitting psf module takes the now normalized psf model and subtracts the contribution.

# %%
dataCubeClean, dataCubeModel = psf.clean_psf(test_cube,
                                             psf_model=psf_data,
                                             x_pos=x_pos,y_pos=y_pos,
                                             debug=True,radius_pos=2.,
                                             inner_rad=25.,outer_rad=35.,
                                             show_debug=True) 
gc.collect()
gc.collect()
# Out:
# clean_psf: PSF subtraction on cube
# clean_psf: The min, max values for PSF model are: -0.0051, 0.0969
# clean_psf: Spectrum of the source
# nice_plot: Setting rcParams
# clean_psf: PSF cleaning performed
# 0

# %% [markdown]
# # Halo Finding

# %% [markdown]
# To preserve memory and remain accurate, we use two parameters here to smooth our data. These are the background corrected data and variance cubes. The function 'smooth_chicube' smooths the cube in the spatial (a_smooth) and spectral (v_smooth) axes.
#
# We use the above plots to set our shrinking parameters min and max lambda.

# %% [markdown]
# ## Cube Smoothing

# %%
chiCube, sChiCube = halos.smooth_chicube(dataCubeClean,statcube=statBg,
                                         min_lambda=1100,
                                         max_lambda=1115,
                                         a_smooth=1,
                                         v_smooth=2)
np.shape(sChiCube)
# Out:
# smooth_chicube: Shrinking cube with given parameters
# smooth_chicube: Smoothing cube with 3D Gaussian Kernel
# (15, 321, 326)

# %% [markdown]
# ----------------

# %% [markdown]
# ## Halo Mask

# %% [markdown]
# halo_mask is the crucial function to the halo finding module. This function performs a friend of friend algorith from a high value voxel nearby the source on the now smoothed and background corrected cube.

# %%
maskHalo = halos.halo_mask(sChiCube,
                           x_pos=x_pos,
                           y_pos=y_pos,
                           z_pos=7,
                           rad_bad_pix=2,
                           rad_max=40,
                           r_connect=2,
                           threshold=2,
                           threshold_type='relative',
                           bad_pixel_mask=None,
                           output=DATA_DIR,
                           debug=True,
                           show_debug=True)
# Out:
# halo_mask: removing inner region around (x,y)=(168.16,159.22)
#           with radius 2 pixels
# location: single source identified
# halo_mask: removing outer region around (x,y)=(168.16,159.22)
#           with radius 40 pixels
# location: single source identified
# halo_mask: defining threshold level
# stat_fullcube: statistic on the cube
# stat_fullcube: average = +0.012
#               median  = +0.018
#               sigma   = +0.226
# stat_fullcube_z: statistic on the cube
# halo_mask: the median value of the voxels is: +0.0177
#           and the sigma is: +0.2258
# halo_mask: the average relative threshold value set to 2.00*0.2258=0.4517
# halo_mask: Saving debug image on /home/ryan.foley/Downloads/J0100COPY.fits_voxelDistribution.pdf
#           in principle the distribution should be gaussian
#           showing only channel 7
# nice_plot: Setting rcParams
# halo_mask: searching for extended emission
#           starting from from (x,y,z)=(168.16,159.220,7)
# halo_mask: the maximum S/N detected is 0.640
#           at the location (x,y,z)=(171,159,1)
# halo_mask: starting to fill the halo mask
# halo_mask: Creating debug image
#           Plotting Channel 1 where the most significant voxel is.
#           The location of this voxel is marked with a red circle
#           The position of the quasar is in blue
# nice_plot: Setting rcParams
# spectral_mask_halo: collapsing halo mask
# spectral_mask_halo: not enough voxels in the mask
# halo_mask: debug image saved in /home/ryan.foley/Downloads/J0100COPY.fits_maskHaloStartingVoxel.pdf
# /home/ryan.foley/PycharmProjects/pycube/pycube/halos.py:400: UserWarning: No contour levels were found within the data range.
#   ax_mask.contour(mask_halo_2D, colors='orangered',
# /home/ryan.foley/PycharmProjects/pycube/pycube/halos.py:433: UserWarning: No contour levels were found within the data range.
#   ax_mask.contour(mask_halo_2D, colors='orangered',
