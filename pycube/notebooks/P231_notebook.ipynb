# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
#  # PSF Sub and Halo Finding

# %% [markdown]
# The code in this notebook is to test and showcase written functions for the python environment 'pycube'. It is designed to analyze MUSE data containers and the surrounding halo around QSOs and neighboring supermassive black holes.

# %% [markdown]
# ## Imports and Data Reading

# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import sep
from photutils import EllipticalAperture
import scipy as sp
from PIL import Image

import pycube
from pycube.core import background
from pycube.core import manip
from pycube import msgs
from pycube import core
from pycube import cubeClass
from pycube import psf
from pycube import halos
from pycube.instruments import vlt_muse
from IPython import embed
import math
import gc

# %% [markdown]
# There are three datasets that have been used for testing this program.

# %% [markdown]
# REQUIEM data with confirmed LYa halo

# %%
DATA_DIR = ('/home/ryan.foley/Downloads/P231COPY.fits')

# %% [markdown]
# --------------------

# %% [markdown]
# Initializes the class object 'test_cube' and initializes the data table by calling 'initialize_file'

# %%
test_cube = cubeClass.IfuCube(DATA_DIR, vlt_muse)

# %%
test_cube.initialize_file()

# %% [markdown]
# This program is written with the assumption those using it know the RA and DEC of their object of interest. To recieve the coordinates in pixel value call the function object_coord from the manip module with your cube object, RA, & DEC as arguments.

# %%
# for P231
x_pos, y_pos = manip.object_coord(test_cube, 231.65765, -20.83354)

# %% [markdown]
# # Data Manipulation

# %% [markdown]
# The code is designed for users to specify how much of the container they want to analyze and on which axis they want to collapse upon. Given these are large data sets, analysis of a smaller section can be beneficial for hardware restraints.

# %% [markdown]
# ## Viewing Data

# %% [markdown]
# We can view the fits table which gives us the header descriptions of values and constants in the data as well as dimensions for our data container. For MUSE data we have a data set and 'stat' set, which is an equally sized variance cube of our data.

# %%
test_cube.hdul.info()
# Out:
# Filename: /home/ryan.foley/Downloads/P231COPY.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU    1355   ()
#   1  DATA          1 ImageHDU        51   (374, 353, 1481)   float32
#   2  STAT          1 ImageHDU        43   (374, 353, 1481)   float32

# %% [markdown]
# The primary row contains just header information but is beneficial when working with this data. Below is the output.

# %%
test_cube.hdul[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                    8 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2019-02-11T13:16:25' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# ORIGIN  = 'ESO-PARANAL'        / European Southern Observatory
# TELESCOP= 'ESO-VLT-U4'         / ESO <TEL>
# INSTRUME= 'MUSE    '           / Instrument used.
# RA      =           231.658861 / [deg] 15:26:38.1 RA (J2000) pointing
# DEC     =            -20.83269 / [deg] -20:49:57.6 DEC (J2000) pointing
# EQUINOX =                2000. / Standard FK5
# RADECSYS= 'FK5     '           / Coordinate system
# EXPTIME =                1482. / Integration time
# MJD-OBS =       57936.01603139 / Obs start
# DATE-OBS= '2017-07-02T00:23:05.000' / Observing date
# UTC     =                1374. / [s] 00:22:53.000 UTC
# LST     =            51734.792 / [s] 14:22:14.792 LST
# PI-COI  = 'UNKNOWN '           / PI-COI name.
# OBSERVER= 'UNKNOWN '           / Name of observer.
# PIPEFILE= 'DATACUBE_FINAL.fits' / Filename of data product
# BUNIT   = '10**(-20)*erg/s/cm**2/Angstrom'
# ARCFILE = 'MUSE.2017-07-02T00:23:05.112.fits' / Archive File Name
# DATAMD5 = 'a7346eaf07a5bb2afb8b825b04b49356' / MD5 checksum
# OBJECT  = 'P231m20 '           / Original target.
# HIERARCH ESO OBS AIRM =    2.8 / Req. max. airmass
# HIERARCH ESO OBS AMBI FWHM = 2. / Req. max. seeing
# HIERARCH ESO OBS AMBI TRANS = '2CLR    ' / Req. sky transparency
# HIERARCH ESO OBS ATM = 'NATM    ' / Req. Atmospheric Turbulence Model
# HIERARCH ESO OBS CONTAINER ID = 1647534 / Scheduling container ID
# HIERARCH ESO OBS CONTAINER TYPE = 'U       ' / Scheduling container type
# HIERARCH ESO OBS CONTRAST = 0. / Req. contrast
# HIERARCH ESO OBS DID = 'ESO-VLT-DIC.OBS-2.0' / OBS Dictionary
# HIERARCH ESO OBS EXECTIME = 3599 / Expected execution time
# HIERARCH ESO OBS GRP = '0       ' / linked blocks
# HIERARCH ESO OBS ID =  1767538 / Observation block ID
# HIERARCH ESO OBS MOON DIST = 30 / Req. min. angular dist. from moon [deg]
# HIERARCH ESO OBS MOON FLI = 1. / Req. max. fractional lunar illum.
# HIERARCH ESO OBS NAME = 'P231m20_1' / OB name
# HIERARCH ESO OBS NTPL =      2 / Number of templates within OB
# HIERARCH ESO OBS OBSERVER = 'UNKNOWN ' / Observer Name
# HIERARCH ESO OBS PI-COI ID = 73422 / ESO internal PI-COI ID
# HIERARCH ESO OBS PI-COI NAME = 'UNKNOWN ' / PI-COI name
# HIERARCH ESO OBS PROG ID = '099.A-0682(A)' / ESO program identification
# HIERARCH ESO OBS START = '2017-07-02T00:16:55' / OB start time
# HIERARCH ESO OBS STREHLRATIO = 0. / Req. strehl ratio
# HIERARCH ESO OBS TARG NAME = 'P231m20 ' / OB target name
# HIERARCH ESO OBS TPLNO =     2 / Template number within OB
# HIERARCH ESO OBS TWILIGHT =  0 / Req. twilight
# HIERARCH ESO OBS WATERVAPOUR = 0. / Req. water vapour
# HIERARCH ESO TPL DID = 'ESO-VLT-DIC.TPL-1.9' / Data dictionary for TPL
# HIERARCH ESO TPL EXPNO =     1 / Exposure number within template
# HIERARCH ESO TPL ID = 'MUSE_wfm-noao_obs_genericoffset' / Template signature ID
# HIERARCH ESO TPL NAME = 'Observation in WFM with user defined offsets' / Templat
# HIERARCH ESO TPL NEXP =      2 / Number of exposures within template
# HIERARCH ESO TPL PRESEQ = 'MUSE_obs_offset.seq' / Sequencer script
# HIERARCH ESO TPL START = '2017-07-02T00:22:05' / TPL start time
# HIERARCH ESO TPL VERSION = '$Revision: 297587 $' / Version of the template
# HIERARCH ESO TEL AIRM END = 1.015 / Airmass at end
# HIERARCH ESO TEL AIRM START = 1.038 / Airmass at start
# HIERARCH ESO TEL ALT =  74.481 / [deg] Alt angle at start
# HIERARCH ESO TEL AMBI FWHM END = 0.8 / [arcsec] Observatory Seeing queried from
# HIERARCH ESO TEL AMBI FWHM START = 0.74 / [arcsec] Observatory Seeing queried fr
# HIERARCH ESO TEL AMBI IRSKY TEMP = -97.1 / Temperature of the IR sky, from radio
# HIERARCH ESO TEL AMBI IWV END = 235.3 / Integrated Water Vapor
# HIERARCH ESO TEL AMBI IWV START = 235.3 / Integrated Water Vapor
# HIERARCH ESO TEL AMBI IWV30D END = 4.05 / IWV at 30deg elev.
# HIERARCH ESO TEL AMBI IWV30D START = 4.05 / IWV at 30deg elev.
# HIERARCH ESO TEL AMBI IWV30DSTD END = 0. / IWV at 30deg elev.
# HIERARCH ESO TEL AMBI IWV30DSTD START = 0. / IWV at 30deg elev.
# HIERARCH ESO TEL AMBI IWVSTD END = 0.01 / Standard Deviation of Integrated Water
# HIERARCH ESO TEL AMBI IWVSTD START = 0.01 / Standard Deviation of Integrated Wat
# HIERARCH ESO TEL AMBI PRES END = 744.68 / [hPa] Observatory ambient air pressure
# HIERARCH ESO TEL AMBI PRES START = 744.38 / [hPa] Observatory ambient air pressu
# HIERARCH ESO TEL AMBI RHUM = 11.5 / [%] Observatory ambient relative humidity qu
# HIERARCH ESO TEL AMBI TAU0 = 0.0028 / [s] Average coherence time
# HIERARCH ESO TEL AMBI TEMP = 13.81 / [deg C] Observatory ambient temperature que
# HIERARCH ESO TEL AMBI WINDDIR = 15.5 / [deg] Observatory ambient wind direction
# HIERARCH ESO TEL AMBI WINDSP = 11.2 / [m/s] Observatory ambient wind speed quer
# HIERARCH ESO TEL AZ =  259.361 / [deg] Az angle at start S=0,W=90
# HIERARCH ESO TEL CHOP ST =   F / True when chopping is active
# HIERARCH ESO TEL DATE = '2000-01-01T00:00:00' / TCS installation date
# HIERARCH ESO TEL DID = 'ESO-VLT-DIC.TCS' / Data dictionary for TEL
# HIERARCH ESO TEL DOME STATUS = 'FULLY-OPEN' / Dome status
# HIERARCH ESO TEL FO POS =   0. / Adapter focus position during tracking
# HIERARCH ESO TEL FOCU ID = 'NB      ' / Telescope focus station ID
# HIERARCH ESO TEL FOCU LEN = 121.561 / [m] Focal length
# HIERARCH ESO TEL FOCU SCALE = 1.705 / [arcsec/mm] Focal scale
# HIERARCH ESO TEL FOCU VALUE = -19.784 / [mm] M2 setting
# HIERARCH ESO TEL GEOELEV = 2648. / [m] Elevation above sea level
# HIERARCH ESO TEL GEOLAT = -24.627 / [deg] Tel geo latitute (+=North)
# HIERARCH ESO TEL GEOLON = -70.404 / [deg] Tel geo longitude (+=East)
# HIERARCH ESO TEL IA FWHM = 0.93 / [arcsec] Delivered seeing corrected by airmass
# HIERARCH ESO TEL IA FWHMLIN = 0.98 / Delivered seeing on IA detector (linear fit
# HIERARCH ESO TEL IA FWHMLINOBS = 0.99 / Delivered seeing on IA detector (linear
# HIERARCH ESO TEL ID = 'v 293191' / TCS version number
# HIERARCH ESO TEL MOON DEC = -4.09847 / [deg] -04:05:54.5 DEC (J2000)
# HIERARCH ESO TEL MOON RA = 201.312374 / [deg] 13:25:14.9 RA (J2000)
# HIERARCH ESO TEL OPER = 'I, Condor' / Telescope Operator
# HIERARCH ESO TEL PARANG END = -114.167 / [deg] Parallactic angle at end
# HIERARCH ESO TEL PARANG START = -107.004 / [deg] Parallactic angle at start
# HIERARCH ESO TEL TARG ALPHA = 152637.841 / Alpha coordinate for the target
# HIERARCH ESO TEL TARG COORDTYPE = 'M       ' / Coordinate type (M=mean A=apparen
# HIERARCH ESO TEL TARG DELTA = -205000.66 / Delta coordinate for the target
# HIERARCH ESO TEL TARG EPOCH = 2000. / [yr] Epoch 1950 or 2000
# HIERARCH ESO TEL TARG EPOCHSYSTEM = 'J       ' / Epoch system (J=Julian / B=Bess
# HIERARCH ESO TEL TARG EQUINOX = 2000. / [yr] Equinox
# HIERARCH ESO TEL TARG PARALLAX = 0. / [arcsec] Parallax
# HIERARCH ESO TEL TARG PMA = 0. / [arcsec/yr] Proper Motion Alpha
# HIERARCH ESO TEL TARG PMD = 0. / [arcsec/yr] Proper motion Delta
# HIERARCH ESO TEL TARG RADVEL = 0. / [km/s] Radial velocity
# HIERARCH ESO TEL TH M1 TEMP = 12.84 / [deg C] M1 superficial temperature
# HIERARCH ESO TEL TRAK STATUS = 'NORMAL  ' / Tracking status
# HIERARCH ESO INS ADC1 DEC = -205329.86044 / [deg] Telescope declination
# HIERARCH ESO INS ADC1 ENC END = 190673 / [Enc] ADC encoder position at end
# HIERARCH ESO INS ADC1 ENC START = 190673 / [Enc] ADC encoder position at start
# HIERARCH ESO INS ADC1 END = -89.9999 / [deg] ADC position angle at end
# HIERARCH ESO INS ADC1 MODE = 'OFF     ' / ADC mode
# HIERARCH ESO INS ADC1 RA = 152739.384135 / [deg] Telescope right ascension
# HIERARCH ESO INS ADC2 DEC = -205329.86044 / [deg] Telescope declination
# HIERARCH ESO INS ADC2 ENC END = 230673 / [Enc] ADC encoder position at end
# HIERARCH ESO INS ADC2 ENC START = 230673 / [Enc] ADC encoder position at start
# HIERARCH ESO INS ADC2 END = -270. / [deg] ADC position angle at end
# HIERARCH ESO INS ADC2 MODE = 'OFF     ' / ADC mode
# HIERARCH ESO INS ADC2 RA = 152739.384135 / [deg] Telescope right ascension
# HIERARCH ESO INS AMPL1 ID = 'ampl1   ' / Pico-amplifier ID
# HIERARCH ESO INS AMPL1 SWSIM = F / If T, pico-amplifier software simulated
# HIERARCH ESO INS AMPL2 FILTER = 'Kron_V  ' / Name of filter in front of PD2
# HIERARCH ESO INS AMPL2 ID = 'ampl2   ' / Pico-amplifier ID
# HIERARCH ESO INS AMPL2 SWSIM = F / If T, pico-amplifier software simulated
# HIERARCH ESO INS DATE = '2000-06-16' / Instrument release date (yyyy-mm-dd).
# HIERARCH ESO INS DID1 = 'MUSE_ICS-295084' / Data dictionary for INSi
# HIERARCH ESO INS DID2 = 'PRIMARY-FITS-1.2' / Data dictionary for INSi
# HIERARCH ESO INS DROT DEC = -205329.86044 / [deg] Telescope declination
# HIERARCH ESO INS DROT ENC END = 22793394 / [Enc] Derotator encoder position at e
# HIERARCH ESO INS DROT ENC START = 22552800 / [Enc] Derotator encoder position at
# HIERARCH ESO INS DROT END = -297.995 / [deg] Derotator position angle at end
# HIERARCH ESO INS DROT MODE = 'SKY     ' / Instrument derotator mode
# HIERARCH ESO INS DROT POSANG = 90. / [deg] Derotator position angle
# HIERARCH ESO INS DROT RA = 152739.384135 / [deg] Telescope right ascension
# HIERARCH ESO INS ID = 'MUSE/176642' / Instrument ID
# HIERARCH ESO INS IFU1 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU1 CHAN = 2 / Integral Field Unit channel
# HIERARCH ESO INS IFU1 DV ID = '16      ' / Detector Vessel ID
# HIERARCH ESO INS IFU1 ID = '01      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU1 ISS ID = '24      ' / Image Slicer System ID
# HIERARCH ESO INS IFU1 PREAMP ID = '36      ' / Detector cable ID
# HIERARCH ESO INS IFU1 SPS ID = '01      ' / Spectograph System ID
# HIERARCH ESO INS IFU1 VPHG ID = '08      ' / Volume Phase Holographic Grating ID
# HIERARCH ESO INS IFU10 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU10 CHAN = 3 / Integral Field Unit channel
# HIERARCH ESO INS IFU10 DV ID = '25      ' / Detector Vessel ID
# HIERARCH ESO INS IFU10 ID = '10      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU10 ISS ID = '10      ' / Image Slicer System ID
# HIERARCH ESO INS IFU10 PREAMP ID = '29      ' / Detector cable ID
# HIERARCH ESO INS IFU10 SPS ID = '10      ' / Spectograph System ID
# HIERARCH ESO INS IFU10 VPHG ID = '19      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU11 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU11 CHAN = 12 / Integral Field Unit channel
# HIERARCH ESO INS IFU11 DV ID = '10      ' / Detector Vessel ID
# HIERARCH ESO INS IFU11 ID = '11      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU11 ISS ID = '03      ' / Image Slicer System ID
# HIERARCH ESO INS IFU11 PREAMP ID = '55      ' / Detector cable ID
# HIERARCH ESO INS IFU11 SPS ID = '11      ' / Spectograph System ID
# HIERARCH ESO INS IFU11 VPHG ID = '15      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU12 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU12 CHAN = 7 / Integral Field Unit channel
# HIERARCH ESO INS IFU12 DV ID = '21      ' / Detector Vessel ID
# HIERARCH ESO INS IFU12 ID = '12      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU12 ISS ID = '09      ' / Image Slicer System ID
# HIERARCH ESO INS IFU12 PREAMP ID = '50      ' / Detector cable ID
# HIERARCH ESO INS IFU12 SPS ID = '12      ' / Spectograph System ID
# HIERARCH ESO INS IFU12 VPHG ID = '21      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU13 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU13 CHAN = 21 / Integral Field Unit channel
# HIERARCH ESO INS IFU13 DV ID = '22      ' / Detector Vessel ID
# HIERARCH ESO INS IFU13 ID = '13      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU13 ISS ID = '08      ' / Image Slicer System ID
# HIERARCH ESO INS IFU13 PREAMP ID = '78      ' / Detector cable ID
# HIERARCH ESO INS IFU13 SPS ID = '13      ' / Spectograph System ID
# HIERARCH ESO INS IFU13 VPHG ID = '18      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU14 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU14 CHAN = 5 / Integral Field Unit channel
# HIERARCH ESO INS IFU14 DV ID = '23      ' / Detector Vessel ID
# HIERARCH ESO INS IFU14 ID = '14      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU14 ISS ID = '12      ' / Image Slicer System ID
# HIERARCH ESO INS IFU14 PREAMP ID = '34      ' / Detector cable ID
# HIERARCH ESO INS IFU14 SPS ID = '14      ' / Spectograph System ID
# HIERARCH ESO INS IFU14 VPHG ID = '20      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU15 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU15 CHAN = 15 / Integral Field Unit channel
# HIERARCH ESO INS IFU15 DV ID = '26      ' / Detector Vessel ID
# HIERARCH ESO INS IFU15 ID = '15      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU15 ISS ID = '15      ' / Image Slicer System ID
# HIERARCH ESO INS IFU15 PREAMP ID = '66      ' / Detector cable ID
# HIERARCH ESO INS IFU15 SPS ID = '15      ' / Spectograph System ID
# HIERARCH ESO INS IFU15 VPHG ID = '22      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU16 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU16 CHAN = 18 / Integral Field Unit channel
# HIERARCH ESO INS IFU16 DV ID = '27      ' / Detector Vessel ID
# HIERARCH ESO INS IFU16 ID = '16      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU16 ISS ID = '16      ' / Image Slicer System ID
# HIERARCH ESO INS IFU16 PREAMP ID = '57      ' / Detector cable ID
# HIERARCH ESO INS IFU16 SPS ID = '16      ' / Spectograph System ID
# HIERARCH ESO INS IFU16 VPHG ID = '17      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU17 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU17 CHAN = 13 / Integral Field Unit channel
# HIERARCH ESO INS IFU17 DV ID = '17      ' / Detector Vessel ID
# HIERARCH ESO INS IFU17 ID = '17      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU17 ISS ID = '13      ' / Image Slicer System ID
# HIERARCH ESO INS IFU17 PREAMP ID = '46      ' / Detector cable ID
# HIERARCH ESO INS IFU17 SPS ID = '17      ' / Spectograph System ID
# HIERARCH ESO INS IFU17 VPHG ID = '16      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU18 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU18 CHAN = 9 / Integral Field Unit channel
# HIERARCH ESO INS IFU18 DV ID = '08      ' / Detector Vessel ID
# HIERARCH ESO INS IFU18 ID = '18      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU18 ISS ID = '19      ' / Image Slicer System ID
# HIERARCH ESO INS IFU18 PREAMP ID = '43      ' / Detector cable ID
# HIERARCH ESO INS IFU18 SPS ID = '18      ' / Spectograph System ID
# HIERARCH ESO INS IFU18 VPHG ID = '26      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU19 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU19 CHAN = 14 / Integral Field Unit channel
# HIERARCH ESO INS IFU19 DV ID = '13      ' / Detector Vessel ID
# HIERARCH ESO INS IFU19 ID = '19      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU19 ISS ID = '18      ' / Image Slicer System ID
# HIERARCH ESO INS IFU19 PREAMP ID = '37      ' / Detector cable ID
# HIERARCH ESO INS IFU19 SPS ID = '19      ' / Spectograph System ID
# HIERARCH ESO INS IFU19 VPHG ID = '23      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU2 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU2 CHAN = 6 / Integral Field Unit channel
# HIERARCH ESO INS IFU2 DV ID = '24      ' / Detector Vessel ID
# HIERARCH ESO INS IFU2 ID = '02      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU2 ISS ID = '06      ' / Image Slicer System ID
# HIERARCH ESO INS IFU2 PREAMP ID = '52      ' / Detector cable ID
# HIERARCH ESO INS IFU2 SPS ID = '02      ' / Spectograph System ID
# HIERARCH ESO INS IFU2 VPHG ID = '03      ' / Volume Phase Holographic Grating ID
# HIERARCH ESO INS IFU20 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU20 CHAN = 10 / Integral Field Unit channel
# HIERARCH ESO INS IFU20 DV ID = '20      ' / Detector Vessel ID
# HIERARCH ESO INS IFU20 ID = '20      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU20 ISS ID = '20      ' / Image Slicer System ID
# HIERARCH ESO INS IFU20 PREAMP ID = '38      ' / Detector cable ID
# HIERARCH ESO INS IFU20 SPS ID = '20      ' / Spectograph System ID
# HIERARCH ESO INS IFU20 VPHG ID = '24      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU21 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU21 CHAN = 11 / Integral Field Unit channel
# HIERARCH ESO INS IFU21 DV ID = '15      ' / Detector Vessel ID
# HIERARCH ESO INS IFU21 ID = '21      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU21 ISS ID = '17      ' / Image Slicer System ID
# HIERARCH ESO INS IFU21 PREAMP ID = '23      ' / Detector cable ID
# HIERARCH ESO INS IFU21 SPS ID = '21      ' / Spectograph System ID
# HIERARCH ESO INS IFU21 VPHG ID = '27      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU22 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU22 CHAN = 24 / Integral Field Unit channel
# HIERARCH ESO INS IFU22 DV ID = '14      ' / Detector Vessel ID
# HIERARCH ESO INS IFU22 ID = '22      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU22 ISS ID = '22      ' / Image Slicer System ID
# HIERARCH ESO INS IFU22 PREAMP ID = '54      ' / Detector cable ID
# HIERARCH ESO INS IFU22 SPS ID = '22      ' / Spectograph System ID
# HIERARCH ESO INS IFU22 VPHG ID = '11      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU23 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU23 CHAN = 23 / Integral Field Unit channel
# HIERARCH ESO INS IFU23 DV ID = '18      ' / Detector Vessel ID
# HIERARCH ESO INS IFU23 ID = '23      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU23 ISS ID = '23      ' / Image Slicer System ID
# HIERARCH ESO INS IFU23 PREAMP ID = '60      ' / Detector cable ID
# HIERARCH ESO INS IFU23 SPS ID = '23      ' / Spectograph System ID
# HIERARCH ESO INS IFU23 VPHG ID = '31      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU24 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU24 CHAN = 1 / Integral Field Unit channel
# HIERARCH ESO INS IFU24 DV ID = '12      ' / Detector Vessel ID
# HIERARCH ESO INS IFU24 ID = '24      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU24 ISS ID = '02      ' / Image Slicer System ID
# HIERARCH ESO INS IFU24 PREAMP ID = '24      ' / Detector cable ID
# HIERARCH ESO INS IFU24 SPS ID = '24      ' / Spectograph System ID
# HIERARCH ESO INS IFU24 VPHG ID = '10      ' / Volume Phase Holographic Grating I
# HIERARCH ESO INS IFU3 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU3 CHAN = 8 / Integral Field Unit channel
# HIERARCH ESO INS IFU3 DV ID = '11      ' / Detector Vessel ID
# HIERARCH ESO INS IFU3 ID = '03      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU3 ISS ID = '14      ' / Image Slicer System ID
# HIERARCH ESO INS IFU3 PREAMP ID = '33      ' / Detector cable ID
# HIERARCH ESO INS IFU3 SPS ID = '03      ' / Spectograph System ID
# HIERARCH ESO INS IFU3 VPHG ID = '14      ' / Volume Phase Holographic Grating ID
# HIERARCH ESO INS IFU4 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU4 CHAN = 4 / Integral Field Unit channel
# HIERARCH ESO INS IFU4 DV ID = '03      ' / Detector Vessel ID
# HIERARCH ESO INS IFU4 ID = '04      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU4 ISS ID = '05      ' / Image Slicer System ID
# HIERARCH ESO INS IFU4 PREAMP ID = '59      ' / Detector cable ID
# HIERARCH ESO INS IFU4 SPS ID = '04      ' / Spectograph System ID
# HIERARCH ESO INS IFU4 VPHG ID = '07      ' / Volume Phase Holographic Grating ID
# HIERARCH ESO INS IFU5 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU5 CHAN = 22 / Integral Field Unit channel
# HIERARCH ESO INS IFU5 DV ID = '09      ' / Detector Vessel ID
# HIERARCH ESO INS IFU5 ID = '05      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU5 ISS ID = '11      ' / Image Slicer System ID
# HIERARCH ESO INS IFU5 PREAMP ID = '77      ' / Detector cable ID
# HIERARCH ESO INS IFU5 SPS ID = '05      ' / Spectograph System ID
# HIERARCH ESO INS IFU5 VPHG ID = '04      ' / Volume Phase Holographic Grating ID
# HIERARCH ESO INS IFU6 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU6 CHAN = 20 / Integral Field Unit channel
# HIERARCH ESO INS IFU6 DV ID = '07      ' / Detector Vessel ID
# HIERARCH ESO INS IFU6 ID = '06      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU6 ISS ID = '01      ' / Image Slicer System ID
# HIERARCH ESO INS IFU6 PREAMP ID = '79      ' / Detector cable ID
# HIERARCH ESO INS IFU6 SPS ID = '06      ' / Spectograph System ID
# HIERARCH ESO INS IFU6 VPHG ID = '06      ' / Volume Phase Holographic Grating ID
# HIERARCH ESO INS IFU7 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU7 CHAN = 17 / Integral Field Unit channel
# HIERARCH ESO INS IFU7 DV ID = '05      ' / Detector Vessel ID
# HIERARCH ESO INS IFU7 ID = '07      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU7 ISS ID = '07      ' / Image Slicer System ID
# HIERARCH ESO INS IFU7 PREAMP ID = '63      ' / Detector cable ID
# HIERARCH ESO INS IFU7 SPS ID = '07      ' / Spectograph System ID
# HIERARCH ESO INS IFU7 VPHG ID = '13      ' / Volume Phase Holographic Grating ID
# HIERARCH ESO INS IFU8 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU8 CHAN = 16 / Integral Field Unit channel
# HIERARCH ESO INS IFU8 DV ID = '06      ' / Detector Vessel ID
# HIERARCH ESO INS IFU8 ID = '08      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU8 ISS ID = '04      ' / Image Slicer System ID
# HIERARCH ESO INS IFU8 PREAMP ID = '56      ' / Detector cable ID
# HIERARCH ESO INS IFU8 SPS ID = '08      ' / Spectograph System ID
# HIERARCH ESO INS IFU8 VPHG ID = '05      ' / Volume Phase Holographic Grating ID
# HIERARCH ESO INS IFU9 CABLE ID = '-1      ' / Detector cable ID
# HIERARCH ESO INS IFU9 CHAN = 19 / Integral Field Unit channel
# HIERARCH ESO INS IFU9 DV ID = '19      ' / Detector Vessel ID
# HIERARCH ESO INS IFU9 ID = '09      ' / Integral Field Unit ID
# HIERARCH ESO INS IFU9 ISS ID = '21      ' / Image Slicer System ID
# HIERARCH ESO INS IFU9 PREAMP ID = '47      ' / Detector cable ID
# HIERARCH ESO INS IFU9 SPS ID = '09      ' / Spectograph System ID
# HIERARCH ESO INS IFU9 VPHG ID = '32      ' / Volume Phase Holographic Grating ID
# HIERARCH ESO INS LAMPNUM =   6 / Number of lamps
# HIERARCH ESO INS MODE = 'WFM-NOAO-N' / Instrument mode used
# HIERARCH ESO INS OPTI1 ID = '1       ' / Optical function unique ID
# HIERARCH ESO INS OPTI1 NAME = 'Blue    ' / Pupil Filter Wheel filter name
# HIERARCH ESO INS OPTI1 NO =  1 / Pupil Filter Wheel slot number
# HIERARCH ESO INS OPTI1 TYPE = 'FILTER  ' / Pupil Filter Wheel element type
# HIERARCH ESO INS OPTI2 ID = '2       ' / Optical function unique ID
# HIERARCH ESO INS OPTI2 NAME = 'WFM     ' / Mode Switching Unit field mode
# HIERARCH ESO INS OPTI2 NO =  2 / Mode Switching Unit position
# HIERARCH ESO INS OPTI2 TYPE = 'FILTER  ' / Optical function element
# HIERARCH ESO INS OPTI3 ID = '1       ' / Optical function unique ID
# HIERARCH ESO INS OPTI3 NAME = 'WFM     ' / Calibration Unit Pickup Mirror Status
# HIERARCH ESO INS OPTI3 NO =  1 / Calibration Pickup Element position
# HIERARCH ESO INS OPTI3 TYPE = 'FREE    ' / Calibration Pickup Element type
# HIERARCH ESO INS OPTI4 ID = '4       ' / Optical function unique ID
# HIERARCH ESO INS OPTI4 NAME = 'Clear   ' / CU Focal Plan mask Wheel mask name
# HIERARCH ESO INS OPTI4 NO =  4 / CU Focal Plan Mask Wheel slot number
# HIERARCH ESO INS OPTI4 TYPE = 'MASK    ' / Optical function element
# HIERARCH ESO INS PATH = '        ' / Optical path used
# HIERARCH ESO INS POS1 ENC = 734003 / [Enc] Position function absolute position
# HIERARCH ESO INS POS1 POS = 12.8 / [mm] Focusing stage position
# HIERARCH ESO INS POS2 ENC = 706631 / [Enc] Position function absolute position
# HIERARCH ESO INS POS2 POS = 14.541 / [mm] Focal Mask Alignment X position
# HIERARCH ESO INS POS3 ENC = 672225 / [Enc] Position function absolute position
# HIERARCH ESO INS POS3 POS = 13.833 / [mm] Focal Mask Alignment Y Position
# HIERARCH ESO INS POS4 ENC = 675481 / [Enc] Position function absolute position
# HIERARCH ESO INS POS4 POS = 13.9 / [mm] Focal Mask Alignment Z Position
# HIERARCH ESO INS PRES1 ID = 'ERP1    ' / Pressure sensor ID
# HIERARCH ESO INS PRES1 NAME = 'Right Enclosure Diff Pressure' / Pressure sensor
# HIERARCH ESO INS PRES1 VAL = -3.37 / [mBar] Right enclosure diff. pressure
# HIERARCH ESO INS PRES2 ID = 'ELP1    ' / Pressure sensor ID
# HIERARCH ESO INS PRES2 NAME = 'Left Enclosure Diff Pressure' / Pressure sensor n
# HIERARCH ESO INS PRES2 VAL = -0.83 / [mBar] Left enclosure diff. pressure
# HIERARCH ESO INS PRES21 VAL = 5.5E-06 / [mBar] Detector 1 pressure
# HIERARCH ESO INS PRES23 VAL = 7.0E-06 / [mBar] Detector 3 pressure
# HIERARCH ESO INS PRES25 VAL = 3.6E-06 / [mBar] Detector 5 pressure
# HIERARCH ESO INS PRES27 VAL = 5.2E-06 / [mBar] Detector 7 pressure
# HIERARCH ESO INS PRES29 VAL = 1.2E-05 / [mBar] Detector 9 pressure
# HIERARCH ESO INS PRES31 VAL = 6.0E-06 / [mBar] Detector 11 pressure
# HIERARCH ESO INS PRES33 VAL = 8.3E-06 / [mBar] Detector 13 pressure
# HIERARCH ESO INS PRES35 VAL = 4.6E-06 / [mBar] Detector 15 pressure
# HIERARCH ESO INS PRES37 VAL = 7.0E-07 / [mBar] Detector 17 pressure
# HIERARCH ESO INS PRES39 VAL = 8.7E-06 / [mBar] Detector 19 pressure
# HIERARCH ESO INS PRES41 VAL = 5.3E-06 / [mBar] Detector 21 pressure
# HIERARCH ESO INS PRES43 VAL = 8.0E-06 / [mBar] Detector 23 pressure
# HIERARCH ESO INS PRES45 VAL = 7.6E-06 / [mBar] Detector 2 pressure
# HIERARCH ESO INS PRES47 VAL = 9.6E-06 / [mBar] Detector 4 pressure
# HIERARCH ESO INS PRES49 VAL = 6.2E-06 / [mBar] Detector 6 pressure
# HIERARCH ESO INS PRES51 VAL = 8.5E-06 / [mBar] Detector 8 pressure
# HIERARCH ESO INS PRES53 VAL = 6.4E-06 / [mBar] Detector 10 pressure
# HIERARCH ESO INS PRES55 VAL = 4.5E-06 / [mBar] Detector 12 pressure
# HIERARCH ESO INS PRES57 VAL = 4.7E-06 / [mBar] Detector 14 pressure
# HIERARCH ESO INS PRES59 VAL = 5.1E-06 / [mBar] Detector 16 pressure
# HIERARCH ESO INS PRES61 VAL = 6.1E-05 / [mBar] Detector 18 pressure
# HIERARCH ESO INS PRES63 VAL = 7.7E-06 / [mBar] Detector 20 pressure
# HIERARCH ESO INS PRES65 VAL = 9.0E-06 / [mBar] Detector 22 pressure
# HIERARCH ESO INS PRES67 VAL = 6.2E-06 / [mBar] Detector 24 pressure
# HIERARCH ESO INS SENS1 ID = 'CURL1   ' / Sensor ID
# HIERARCH ESO INS SENS1 NAME = 'INS LAMP1 Current' / Sensor common name
# HIERARCH ESO INS SENS1 VAL = 3 / [10-1 A] Lamp 1 current value
# HIERARCH ESO INS SENS10 ID = 'TTL3    ' / Sensor ID
# HIERARCH ESO INS SENS10 NAME = 'INS LAMP3 Total Time' / Sensor common name
# HIERARCH ESO INS SENS10 VAL = 66. / [h] Lamp #3 total time
# HIERARCH ESO INS SENS11 ID = 'OVTL3   ' / Sensor ID
# HIERARCH ESO INS SENS11 NAME = 'INS LAMP3 Over Temp. Alarm' / Sensor common name
# HIERARCH ESO INS SENS11 VAL = F / Lamp #3 over temperature alarm
# HIERARCH ESO INS SENS12 ID = 'ALTL3   ' / Sensor ID
# HIERARCH ESO INS SENS12 NAME = 'INS LAMP3 Temp. Latched Alarm' / Sensor common n
# HIERARCH ESO INS SENS12 VAL = F / Lamp #3 over temperature latched alarm
# HIERARCH ESO INS SENS13 ID = 'CURL4   ' / Sensor ID
# HIERARCH ESO INS SENS13 NAME = 'INS LAMP4 Current' / Sensor common name
# HIERARCH ESO INS SENS13 VAL = 20 / [10-1 mA] Lamp #4 current value
# HIERARCH ESO INS SENS14 ID = 'TTL4    ' / Sensor ID
# HIERARCH ESO INS SENS14 NAME = 'INS LAMP4 Total Time' / Sensor common name
# HIERARCH ESO INS SENS14 VAL = 255. / [h] Lamp #4 total time
# HIERARCH ESO INS SENS15 ID = 'OVTL4   ' / Sensor ID
# HIERARCH ESO INS SENS15 NAME = 'INS LAMP4 Over Temp. Alarm' / Sensor common name
# HIERARCH ESO INS SENS15 VAL = F / Lamp #4 over temperature alarm
# HIERARCH ESO INS SENS16 ID = 'ALTL4   ' / Sensor ID
# HIERARCH ESO INS SENS16 NAME = 'INS LAMP4 Temp. Latched Alarm' / Sensor common n
# HIERARCH ESO INS SENS16 VAL = F / Lamp #4 over temperature latched alarm
# HIERARCH ESO INS SENS17 ID = 'CURL5   ' / Sensor ID
# HIERARCH ESO INS SENS17 NAME = 'INS LAMP5 Current' / Sensor common name
# HIERARCH ESO INS SENS17 VAL = 24 / [10-2 A] Lamp #5 current value
# HIERARCH ESO INS SENS18 ID = 'TTL5    ' / Sensor ID
# HIERARCH ESO INS SENS18 NAME = 'INS LAMP5 Total Time' / Sensor common name
# HIERARCH ESO INS SENS18 VAL = 945. / [h] Lamp #5 total time
# HIERARCH ESO INS SENS19 ID = 'OVTL5   ' / Sensor ID
# HIERARCH ESO INS SENS19 NAME = 'INS LAMP5 Over Temp. Alarm' / Sensor common name
# HIERARCH ESO INS SENS19 VAL = F / Lamp #5 over temperature alarm
# HIERARCH ESO INS SENS2 ID = 'TTL1    ' / Sensor ID
# HIERARCH ESO INS SENS2 NAME = 'INS LAMP1 Total Time' / Sensor common name
# HIERARCH ESO INS SENS2 VAL = 464. / [h] Lamp #1 total time
# HIERARCH ESO INS SENS20 ID = 'ALTL5   ' / Sensor ID
# HIERARCH ESO INS SENS20 NAME = 'INS LAMP5 Temp. Latched Alarm' / Sensor common n
# HIERARCH ESO INS SENS20 VAL = F / Lamp #5 over temperature latched alarm
# HIERARCH ESO INS SENS21 ID = 'CURL6   ' / Sensor ID
# HIERARCH ESO INS SENS21 NAME = 'INS LAMP6 Current' / Sensor common name
# HIERARCH ESO INS SENS21 VAL = 34 / [10-2 A] Lamp #6 current value
# HIERARCH ESO INS SENS22 ID = 'TTL6    ' / Sensor ID
# HIERARCH ESO INS SENS22 NAME = 'INS LAMP6 Total Time' / Sensor common name
# HIERARCH ESO INS SENS22 VAL = 138. / [h] Lamp #6 total time
# HIERARCH ESO INS SENS23 ID = 'OVTL6   ' / Sensor ID
# HIERARCH ESO INS SENS23 NAME = 'INS LAMP6 Over Temp. Alarm' / Sensor common name
# HIERARCH ESO INS SENS23 VAL = F / Lamp #6 over temperature alarm
# HIERARCH ESO INS SENS24 ID = 'ALTL6   ' / Sensor ID
# HIERARCH ESO INS SENS24 NAME = 'INS LAMP6 Temp. Latched Alarm' / Sensor common n
# HIERARCH ESO INS SENS24 VAL = F / Lamp #6 over temperature latched alarm
# HIERARCH ESO INS SENS3 ID = 'OVTL1   ' / Sensor ID
# HIERARCH ESO INS SENS3 NAME = 'INS LAMP1 Over Temp. Alarm' / Sensor common name
# HIERARCH ESO INS SENS3 VAL = F / Lamp #1 over temperature alarm
# HIERARCH ESO INS SENS31 ID = 'CAW1    ' / Sensor ID
# HIERARCH ESO INS SENS31 NAME = 'Cooling Warning 1' / Sensor common name
# HIERARCH ESO INS SENS31 STAT = F / Cabinet cooling system warning
# HIERARCH ESO INS SENS32 ID = 'DOR1    ' / Sensor ID
# HIERARCH ESO INS SENS32 NAME = 'Door 1 Control' / Sensor common name
# HIERARCH ESO INS SENS32 STAT = F / Cabinet front door switch
# HIERARCH ESO INS SENS33 ID = 'DOR2    ' / Sensor ID
# HIERARCH ESO INS SENS33 NAME = 'Door 2 Control' / Sensor common name
# HIERARCH ESO INS SENS33 STAT = F / Cabinet rear door switch
# HIERARCH ESO INS SENS34 ID = 'CAL1    ' / Sensor ID
# HIERARCH ESO INS SENS34 NAME = 'Cooling Alarm 1' / Sensor common name
# HIERARCH ESO INS SENS34 STAT = F / Cabinet cooling system alarm
# HIERARCH ESO INS SENS4 ID = 'ALTL1   ' / Sensor ID
# HIERARCH ESO INS SENS4 NAME = 'INS LAMP1 Temp. Latched Alarm' / Sensor common na
# HIERARCH ESO INS SENS4 VAL = F / Lamp #1 over temperature latched alarm
# HIERARCH ESO INS SENS40 ID = 'CAF2    ' / Sensor ID
# HIERARCH ESO INS SENS40 NAME = 'Flow Rate' / Sensor common name
# HIERARCH ESO INS SENS40 VAL = 206. / [l/h] Cabinet flow rate
# HIERARCH ESO INS SENS46 ID = 'XMAS1   ' / Sensor ID
# HIERARCH ESO INS SENS46 NAME = 'Xtra Muse Aperture Shutter' / Sensor common name
# HIERARCH ESO INS SENS46 STAT = F / Xtra Muse Aperture Shutter switch
# HIERARCH ESO INS SENS5 ID = 'CURL2   ' / Sensor ID
# HIERARCH ESO INS SENS5 NAME = 'INS LAMP2 Current' / Sensor common name
# HIERARCH ESO INS SENS5 VAL = 0 / [10-1 A] Lamp #2 current value
# HIERARCH ESO INS SENS51 ID = 'ECH1    ' / Sensor ID
# HIERARCH ESO INS SENS51 NAME = 'Fore Optics Hygrometry' / Sensor common name
# HIERARCH ESO INS SENS51 VAL = 15.44 / [%] Fore Optics hygrometry
# HIERARCH ESO INS SENS6 ID = 'TTL2    ' / Sensor ID
# HIERARCH ESO INS SENS6 NAME = 'INS LAMP2 Total Time' / Sensor common name
# HIERARCH ESO INS SENS6 VAL = 1499. / [h] Lamp #2 total time
# HIERARCH ESO INS SENS7 ID = 'OVTL2   ' / Sensor ID
# HIERARCH ESO INS SENS7 NAME = 'INS LAMP2 Over Temp. Alarm' / Sensor common name
# HIERARCH ESO INS SENS7 VAL = F / Lamp #2 over temperature alarm
# HIERARCH ESO INS SENS76 VAL = 1.6E-11 / [mBar] Test sensor value
# HIERARCH ESO INS SENS8 ID = 'ALTL2   ' / Sensor ID
# HIERARCH ESO INS SENS8 NAME = 'INS LAMP2 Temp. Latched Alarm' / Sensor common na
# HIERARCH ESO INS SENS8 VAL = F / Lamp #2 over temperature latched alarm
# HIERARCH ESO INS SENS9 ID = 'CURL3   ' / Sensor ID
# HIERARCH ESO INS SENS9 NAME = 'INS LAMP3 Current' / Sensor common name
# HIERARCH ESO INS SENS9 VAL = 30 / [10-1 mA] Lamp #3 current value
# HIERARCH ESO INS SENSOR1 ID = 'clx1    ' / Sensor device unique id
# HIERARCH ESO INS SENSOR1 NAME = 'INS LAMP1 Data' / Sensor device common name
# HIERARCH ESO INS SENSOR10 ID = 'hsk1    ' / Sensor device unique id
# HIERARCH ESO INS SENSOR10 NAME = 'HSK Encl/IFU env' / Sensor device common name
# HIERARCH ESO INS SENSOR13 ID = 'cryom   ' / Sensor device unique id
# HIERARCH ESO INS SENSOR13 NAME = 'Cryogenic controller monitoring' / Sensor devi
# HIERARCH ESO INS SENSOR13 SWSIM = T / If T, sensor is software simulated
# HIERARCH ESO INS SENSOR2 ID = 'clx2    ' / Sensor device unique id
# HIERARCH ESO INS SENSOR2 NAME = 'INS LAMP2 Data' / Sensor device common name
# HIERARCH ESO INS SENSOR3 ID = 'clx3    ' / Sensor device unique id
# HIERARCH ESO INS SENSOR3 NAME = 'INS LAMP3 Data' / Sensor device common name
# HIERARCH ESO INS SENSOR4 ID = 'clx4    ' / Sensor device unique id
# HIERARCH ESO INS SENSOR4 NAME = 'INS LAMP4 Data' / Sensor device common name
# HIERARCH ESO INS SENSOR5 ID = 'clx5    ' / Sensor device unique id
# HIERARCH ESO INS SENSOR5 NAME = 'INS LAMP5 Data' / Sensor device common name
# HIERARCH ESO INS SENSOR6 ID = 'clx6    ' / Sensor device unique id
# HIERARCH ESO INS SENSOR6 NAME = 'INS LAMP6 Data' / Sensor device common name
# HIERARCH ESO INS SENSOR7 ID = 'dis1    ' / Sensor device unique id
# HIERARCH ESO INS SENSOR7 NAME = 'Cabinet Dig. Sensor' / Sensor device common nam
# HIERARCH ESO INS SENSOR8 ID = 'ccc1    ' / Sensor device unique id
# HIERARCH ESO INS SENSOR8 NAME = 'Cooling controller' / Sensor device common name
# HIERARCH ESO INS SENSOR9 ID = 'dis2    ' / Sensor device unique id
# HIERARCH ESO INS SENSOR9 NAME = 'Safety Switches' / Sensor device common name
# HIERARCH ESO INS SHUT1 ID = 'CSH1    ' / Lamp shutter ID
# HIERARCH ESO INS SHUT1 NAME = 'ContB   ' / Lamp shutter name
# HIERARCH ESO INS SHUT1 ST =  F / Lamp shutter open
# HIERARCH ESO INS SHUT2 ID = 'CSH2    ' / Lamp shutter ID
# HIERARCH ESO INS SHUT2 NAME = 'ContR   ' / Lamp shutter name
# HIERARCH ESO INS SHUT2 ST =  F / Lamp shutter open
# HIERARCH ESO INS SHUT3 ID = 'CSH3    ' / Lamp shutter ID
# HIERARCH ESO INS SHUT3 NAME = 'Ne      ' / Lamp shutter name
# HIERARCH ESO INS SHUT3 ST =  F / Lamp shutter open
# HIERARCH ESO INS SHUT4 ID = 'CSH4    ' / Lamp shutter ID
# HIERARCH ESO INS SHUT4 NAME = 'Xe      ' / Lamp shutter name
# HIERARCH ESO INS SHUT4 ST =  F / Lamp shutter open
# HIERARCH ESO INS SHUT5 ID = 'CSH5    ' / Lamp shutter ID
# HIERARCH ESO INS SHUT5 NAME = 'HgCd    ' / Lamp shutter name
# HIERARCH ESO INS SHUT5 ST =  F / Lamp shutter open
# HIERARCH ESO INS SHUT6 ID = 'CSH6    ' / Lamp shutter ID
# HIERARCH ESO INS SHUT6 NAME = 'Ne      ' / Lamp shutter name
# HIERARCH ESO INS SHUT6 ST =  F / Lamp shutter open
# HIERARCH ESO INS SWSIM = 'NORMAL  ' / Software simulation
# HIERARCH ESO INS TEMP1 ID = 'CAOT    ' / Temperature sensor ID
# HIERARCH ESO INS TEMP1 NAME = 'Cooling Outlet Temperature' / Temperature sensor
# HIERARCH ESO INS TEMP1 VAL = 11.4 / [C] Cooling outlet temperature
# HIERARCH ESO INS TEMP10 ID = 'ELT2    ' / Temperature sensor ID
# HIERARCH ESO INS TEMP10 NAME = 'Left Enclosure Temperature 2' / Temperature sens
# HIERARCH ESO INS TEMP10 VAL = 14.3 / [C] Left enclosure temperature #2
# HIERARCH ESO INS TEMP11 ID = 'ILT1    ' / Temperature sensor ID
# HIERARCH ESO INS TEMP11 NAME = 'Left IFU Temperature 1' / Temperature sensor nam
# HIERARCH ESO INS TEMP11 VAL = 14.43 / [C] Left IFU temperature
# HIERARCH ESO INS TEMP13 ID = 'ECT1    ' / Temperature sensor ID
# HIERARCH ESO INS TEMP13 NAME = 'Central Enclosure Temperature 1' / Temperature s
# HIERARCH ESO INS TEMP13 VAL = 15.05 / [C] Central enclosure temperature #1
# HIERARCH ESO INS TEMP14 ID = 'ECT2    ' / Temperature sensor ID
# HIERARCH ESO INS TEMP14 NAME = 'Central Enclosure Temperature 2' / Temperature s
# HIERARCH ESO INS TEMP14 VAL = 15.21 / [C] Central enclosure temperature #2
# HIERARCH ESO INS TEMP16 ID = 'EBT1    ' / Temperature sensor ID
# HIERARCH ESO INS TEMP16 NAME = 'EBB Crate Temperature' / Temperature sensor name
# HIERARCH ESO INS TEMP16 VAL = 15.77 / [C] EBB crate temperature
# HIERARCH ESO INS TEMP17 ID = 'EBT2    ' / Temperature sensor ID
# HIERARCH ESO INS TEMP17 NAME = 'Heat Exchanger Temperature' / Temperature sensor
# HIERARCH ESO INS TEMP17 VAL = 25.79 / [C] Heat exchanger temperature
# HIERARCH ESO INS TEMP2 ID = 'CAIT    ' / Temperature sensor ID
# HIERARCH ESO INS TEMP2 NAME = 'Cooling Inlet Temperature' / Temperature sensor n
# HIERARCH ESO INS TEMP2 VAL = 9.29 / [C] Cooling inlet temperature
# HIERARCH ESO INS TEMP21 VAL = 162.99 / [K] Detector 1 temperature
# HIERARCH ESO INS TEMP23 VAL = 163.01 / [K] Detector 3 temperature
# HIERARCH ESO INS TEMP25 VAL = 163. / [K] Detector 5 temperature
# HIERARCH ESO INS TEMP27 VAL = 163. / [K] Detector 7 temperature
# HIERARCH ESO INS TEMP29 VAL = 163. / [K] Detector 9 temperature
# HIERARCH ESO INS TEMP3 ID = 'CACT    ' / Temperature sensor ID
# HIERARCH ESO INS TEMP3 NAME = 'Cabinet Temperature' / Temperature sensor name
# HIERARCH ESO INS TEMP3 VAL = 16.94 / [C] Cabinet temperature
# HIERARCH ESO INS TEMP31 VAL = 163. / [K] Detector 11 temperature
# HIERARCH ESO INS TEMP33 VAL = 163. / [K] Detector 13 temperature
# HIERARCH ESO INS TEMP35 VAL = 163. / [K] Detector 15 temperature
# HIERARCH ESO INS TEMP37 VAL = 162.99 / [K] Detector 17 temperature
# HIERARCH ESO INS TEMP39 VAL = 163.01 / [K] Detector 19 temperature
# HIERARCH ESO INS TEMP4 ID = 'CAAT    ' / Temperature sensor ID
# HIERARCH ESO INS TEMP4 NAME = 'Ambient Temperature' / Temperature sensor name
# HIERARCH ESO INS TEMP4 VAL = 12.75 / [C] Ambient temperature
# HIERARCH ESO INS TEMP41 VAL = 163. / [K] Detector 21 temperature
# HIERARCH ESO INS TEMP43 VAL = 163. / [K] Detector 23 temperature
# HIERARCH ESO INS TEMP45 VAL = 163.01 / [K] Detector 2 temperature
# HIERARCH ESO INS TEMP47 VAL = 163. / [K] Detector 4 temperature
# HIERARCH ESO INS TEMP49 VAL = 163. / [K] Detector 6 temperature
# HIERARCH ESO INS TEMP5 ID = 'ERT1    ' / Temperature sensor ID
# HIERARCH ESO INS TEMP5 NAME = 'Right Enclosure Temperature 1' / Temperature sens
# HIERARCH ESO INS TEMP5 VAL = 15.01 / [C] Right enclosure temperature #1
# HIERARCH ESO INS TEMP51 VAL = 163. / [K] Detector 8 temperature
# HIERARCH ESO INS TEMP53 VAL = 162.99 / [K] Detector 10 temperature
# HIERARCH ESO INS TEMP55 VAL = 162.99 / [K] Detector 12 temperature
# HIERARCH ESO INS TEMP57 VAL = 162.99 / [K] Detector 14 temperature
# HIERARCH ESO INS TEMP59 VAL = 163.01 / [K] Detector 16 temperature
# HIERARCH ESO INS TEMP6 ID = 'ERT2    ' / Temperature sensor ID
# HIERARCH ESO INS TEMP6 NAME = 'Right Enclosure Temperature 2' / Temperature sens
# HIERARCH ESO INS TEMP6 VAL = 14.72 / [C] Right enclosure temperature #2
# HIERARCH ESO INS TEMP61 VAL = 163.03 / [K] Detector 18 temperature
# HIERARCH ESO INS TEMP63 VAL = 162.98 / [K] Detector 20 temperature
# HIERARCH ESO INS TEMP65 VAL = 163.01 / [K] Detector 22 temperature
# HIERARCH ESO INS TEMP67 VAL = 163.01 / [K] Detector 24 temperature
# HIERARCH ESO INS TEMP7 ID = 'IRT1    ' / Temperature sensor ID
# HIERARCH ESO INS TEMP7 NAME = 'Right IFU Temperature 1' / Temperature sensor nam
# HIERARCH ESO INS TEMP7 VAL = 14.32 / [C] Right IFU temperature
# HIERARCH ESO INS TEMP9 ID = 'ELT1    ' / Temperature sensor ID
# HIERARCH ESO INS TEMP9 NAME = 'Left Enclosure Temperature 1' / Temperature senso
# ...
# HIERARCH ESO OCS SGS AG FWHMY MED = 0.794 / [arcsec] AG FWHM Y median value
# HIERARCH ESO OCS SGS AG FWHMY MIN = 0.691 / [arcsec] AG FWHM Y minimum value
# HIERARCH ESO OCS SGS AG FWHMY RMS = 0.057 / [arcsec] AG FWHM Y RMS value
# HIERARCH ESO OCS SGS ALGO NAME = 'CORRELATOR' / Centering method
# HIERARCH ESO OCS SGS ALGO WIN SCALE = 6. / Factor for window size
# HIERARCH ESO OCS SGS ALGO WIN SIZE = 56 / [pix] Window size
# HIERARCH ESO OCS SGS FLUX AVG = 38450. / [ADU] SGS flux mean value
# HIERARCH ESO OCS SGS FLUX MAX = 47330. / [ADU] SGS flux maximum value
# HIERARCH ESO OCS SGS FLUX MED = 39440. / [ADU] SGS flux median value
# HIERARCH ESO OCS SGS FLUX MIN = 19510. / [ADU] SGS flux minimum value
# HIERARCH ESO OCS SGS FLUX RMS = 4597. / [ADU] SGS flux RMS value
# HIERARCH ESO OCS SGS FLUX RMSPRC = 11.7 / [%] SGS flux RMS percentage value
# HIERARCH ESO OCS SGS FWHM AVG = 0.782 / [arcsec] SGS FWHM mean value
# HIERARCH ESO OCS SGS FWHM MAX = 1.445 / [arcsec] SGS FWHM maximum value
# HIERARCH ESO OCS SGS FWHM MED = 0.753 / [arcsec] SGS FWHM median value
# HIERARCH ESO OCS SGS FWHM MIN = 0.397 / [arcsec] SGS FWHM minimum value
# HIERARCH ESO OCS SGS FWHM RMS = 0.196 / [arcsec] SGS FWHM RMS value
# HIERARCH ESO OCS SGS LOOP CLOSED PRCTG = 100. / SGS closed loop percentage
# HIERARCH ESO OCS SGS LOOP GAIN = 0.95 / SGS loop gain
# HIERARCH ESO OCS SGS LOOP MODE = 2 / SGS loop mode
# HIERARCH ESO OCS SGS LOOP MODENAME = 'GUIDING ' / SGS loop mode name
# HIERARCH ESO OCS SGS LOOP PERIOD = 126 / [s] SGS loop period
# HIERARCH ESO OCS SGS LOOP ST = T / SGS loop status
# HIERARCH ESO OCS SGS NOBJ =  2 / Nb of objects for slow-guiding
# HIERARCH ESO OCS SGS OBJ1 FLUX = 13350. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ1 REJECTED = T / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ1 USED PRCTG = 0. / % of time SGS object #i has been us
# HIERARCH ESO OCS SGS OBJ1 X = 625.6 / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ1 Y = 874.3 / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ10 FLUX = 0. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ10 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ10 USED PRCTG = 0. / % of time SGS object #i has been u
# HIERARCH ESO OCS SGS OBJ10 X = 0. / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ10 Y = 0. / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ2 FLUX = 23290. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ2 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ2 USED PRCTG = 100. / % of time SGS object #i has been
# HIERARCH ESO OCS SGS OBJ2 X = 518.3 / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ2 Y = 57.3 / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ3 FLUX = 0. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ3 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ3 USED PRCTG = 0. / % of time SGS object #i has been us
# HIERARCH ESO OCS SGS OBJ3 X = 0. / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ3 Y = 0. / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ4 FLUX = 0. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ4 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ4 USED PRCTG = 0. / % of time SGS object #i has been us
# HIERARCH ESO OCS SGS OBJ4 X = 0. / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ4 Y = 0. / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ5 FLUX = 0. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ5 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ5 USED PRCTG = 0. / % of time SGS object #i has been us
# HIERARCH ESO OCS SGS OBJ5 X = 0. / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ5 Y = 0. / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ6 FLUX = 0. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ6 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ6 USED PRCTG = 0. / % of time SGS object #i has been us
# HIERARCH ESO OCS SGS OBJ6 X = 0. / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ6 Y = 0. / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ7 FLUX = 0. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ7 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ7 USED PRCTG = 0. / % of time SGS object #i has been us
# HIERARCH ESO OCS SGS OBJ7 X = 0. / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ7 Y = 0. / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ8 FLUX = 0. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ8 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ8 USED PRCTG = 0. / % of time SGS object #i has been us
# HIERARCH ESO OCS SGS OBJ8 X = 0. / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ8 Y = 0. / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ9 FLUX = 0. / [ADU] Flux of the SGS object #i
# HIERARCH ESO OCS SGS OBJ9 REJECTED = F / Rejected flag of the SGS object #i
# HIERARCH ESO OCS SGS OBJ9 USED PRCTG = 0. / % of time SGS object #i has been us
# HIERARCH ESO OCS SGS OBJ9 X = 0. / X-position of the SGS object #i
# HIERARCH ESO OCS SGS OBJ9 Y = 0. / Y-position of the SGS object #i
# HIERARCH ESO OCS SGS OFFSET DECAVG = 0.002 / [arcsec] SGS delta offset mean valu
# HIERARCH ESO OCS SGS OFFSET DECMAX = 0.042 / [arcsec] SGS delta offset maximum v
# HIERARCH ESO OCS SGS OFFSET DECMED = 0. / [arcsec] SGS delta offset median va
# HIERARCH ESO OCS SGS OFFSET DECMIN = -0.019 / [arcsec] SGS delta offset minimum
# HIERARCH ESO OCS SGS OFFSET DECRMS = 0.013 / [arcsec] SGS delta offset RMS value
# HIERARCH ESO OCS SGS OFFSET DECSUM = 0.023 / [arcsec] SGS cumulated delta offset
# HIERARCH ESO OCS SGS OFFSET ENABLED = T / SGS offsetting status
# HIERARCH ESO OCS SGS OFFSET RAAVG = 0.001 / [arcsec] SGS alpha offset mean value
# HIERARCH ESO OCS SGS OFFSET RAMAX = 0.02 / [arcsec] SGS alpha offset maximum va
# HIERARCH ESO OCS SGS OFFSET RAMED = 0. / [arcsec] SGS alpha offset median val
# HIERARCH ESO OCS SGS OFFSET RAMIN = -0.01 / [arcsec] SGS alpha offset minimum v
# HIERARCH ESO OCS SGS OFFSET RARMS = 0.006 / [arcsec] SGS alpha offset RMS value
# HIERARCH ESO OCS SGS OFFSET RASUM = 0.01 / [arcsec] SGS cumulated alpha offset
# HIERARCH ESO OCS SGS OFFSET THRMAX = 1. / [arcsec] Alpha/Delta max offset thr
# HIERARCH ESO OCS SGS OFFSET THRMIN = 0.02 / [arcsec] Alpha/Delta min offset thr
# HIERARCH ESO OCS SGS PIXSCALE X = 0.093 / [arcsec/pix] X pixel scale of SGS
# HIERARCH ESO OCS SGS PIXSCALE Y = 0.0895 / [arcsec/pix] Y pixel scale of SGS
# HIERARCH ESO OCS SGS REF NBIMG = 1 / Number of images for reference image
# HIERARCH ESO OCS SGS REF SAVE = 'MUSE_SGS_REF_START_POS.fits' / SGS reference fi
# HIERARCH ESO OCS SGS REF ST = T / SGS reference image acquisition
# HIERARCH ESO OCS SGS REJECT PRCTG = 0. / Image rejection ratio
# HIERARCH ESO OCS TEL ACCESS = 'NORMAL  ' / Sub-system access mode.
# HIERARCH ESO SEQ OFFSET COORDS = 'SKY     ' / Offset coordinate type
# HIERARCH ESO SEQ OFFSET CUM ALPHA = 4. / [arcsec] Cumulative alpha offset
# HIERARCH ESO SEQ OFFSET CUM DELTA = 3. / [arcsec] Cumulative delta offset
# HIERARCH ESO SEQ OFFSET REL ALPHA = 4. / [arcsec] Relative alpha offset
# HIERARCH ESO SEQ OFFSET REL DELTA = 3. / [arcsec] Relative delta offset
# HIERARCH ESO QC EXPCOMB LAMBDA = 8425. / [Angstrom] Wavelength of plane in combi
# HIERARCH ESO QC EXPCOMB NDET = 14 / Number of detected sources in combined cube.
# HIERARCH ESO QC EXPCOMB POS1 X = 151. / [pix] Position of source k in x-directio
# HIERARCH ESO QC EXPCOMB POS1 Y = 15. / [pix] Position of source k in y-direction
# HIERARCH ESO QC EXPCOMB FWHM1 X = 0.6384976 / [arcsec] FWHM of source k in x-dir
# HIERARCH ESO QC EXPCOMB FWHM1 Y = 0.6583381 / [arcsec] FWHM of source k in y-dir
# HIERARCH ESO QC EXPCOMB POS2 X = 251. / [pix] Position of source k in x-directio
# HIERARCH ESO QC EXPCOMB POS2 Y = 58. / [pix] Position of source k in y-direction
# HIERARCH ESO QC EXPCOMB FWHM2 X = 0.7186869 / [arcsec] FWHM of source k in x-dir
# HIERARCH ESO QC EXPCOMB FWHM2 Y = 0.6672721 / [arcsec] FWHM of source k in y-dir
# HIERARCH ESO QC EXPCOMB POS3 X = 217. / [pix] Position of source k in x-directio
# HIERARCH ESO QC EXPCOMB POS3 Y = 67. / [pix] Position of source k in y-direction
# HIERARCH ESO QC EXPCOMB FWHM3 X = 0.6415821 / [arcsec] FWHM of source k in x-dir
# HIERARCH ESO QC EXPCOMB FWHM3 Y = 0.6692708 / [arcsec] FWHM of source k in y-dir
# HIERARCH ESO QC EXPCOMB POS4 X = 152. / [pix] Position of source k in x-directio
# HIERARCH ESO QC EXPCOMB POS4 Y = 72. / [pix] Position of source k in y-direction
# HIERARCH ESO QC EXPCOMB FWHM4 X = 0.6481065 / [arcsec] FWHM of source k in x-dir
# HIERARCH ESO QC EXPCOMB FWHM4 Y = 0.6488395 / [arcsec] FWHM of source k in y-dir
# HIERARCH ESO QC EXPCOMB POS5 X = 184. / [pix] Position of source k in x-directio
# HIERARCH ESO QC EXPCOMB POS5 Y = 111. / [pix] Position of source k in y-directio
# HIERARCH ESO QC EXPCOMB FWHM5 X = 0.6959644 / [arcsec] FWHM of source k in x-dir
# HIERARCH ESO QC EXPCOMB FWHM5 Y = 0.6281706 / [arcsec] FWHM of source k in y-dir
# HIERARCH ESO QC EXPCOMB POS6 X = 73. / [pix] Position of source k in x-direction
# HIERARCH ESO QC EXPCOMB POS6 Y = 127. / [pix] Position of source k in y-directio
# HIERARCH ESO QC EXPCOMB FWHM6 X = 0.6804007 / [arcsec] FWHM of source k in x-dir
# HIERARCH ESO QC EXPCOMB FWHM6 Y = 0.6706885 / [arcsec] FWHM of source k in y-dir
# HIERARCH ESO QC EXPCOMB POS7 X = 25. / [pix] Position of source k in x-direction
# HIERARCH ESO QC EXPCOMB POS7 Y = 138. / [pix] Position of source k in y-directio
# HIERARCH ESO QC EXPCOMB FWHM7 X = 0.6798558 / [arcsec] FWHM of source k in x-dir
# HIERARCH ESO QC EXPCOMB FWHM7 Y = 0.6717536 / [arcsec] FWHM of source k in y-dir
# HIERARCH ESO QC EXPCOMB POS8 X = 119. / [pix] Position of source k in x-directio
# HIERARCH ESO QC EXPCOMB POS8 Y = 136. / [pix] Position of source k in y-directio
# HIERARCH ESO QC EXPCOMB FWHM8 X = 0.6910116 / [arcsec] FWHM of source k in x-dir
# HIERARCH ESO QC EXPCOMB FWHM8 Y = 0.5894433 / [arcsec] FWHM of source k in y-dir
# HIERARCH ESO QC EXPCOMB POS9 X = 307. / [pix] Position of source k in x-directio
# HIERARCH ESO QC EXPCOMB POS9 Y = 187. / [pix] Position of source k in y-directio
# HIERARCH ESO QC EXPCOMB FWHM9 X = 0.6717488 / [arcsec] FWHM of source k in x-dir
# HIERARCH ESO QC EXPCOMB FWHM9 Y = 0.6387529 / [arcsec] FWHM of source k in y-dir
# HIERARCH ESO QC EXPCOMB POS10 X = 95. / [pix] Position of source k in x-directio
# HIERARCH ESO QC EXPCOMB POS10 Y = 236. / [pix] Position of source k in y-directi
# HIERARCH ESO QC EXPCOMB FWHM10 X = 0.6704673 / [arcsec] FWHM of source k in x-di
# HIERARCH ESO QC EXPCOMB FWHM10 Y = 0.6591037 / [arcsec] FWHM of source k in y-di
# HIERARCH ESO QC EXPCOMB POS11 X = 336. / [pix] Position of source k in x-directi
# HIERARCH ESO QC EXPCOMB POS11 Y = 238. / [pix] Position of source k in y-directi
# HIERARCH ESO QC EXPCOMB FWHM11 X = 0.7247661 / [arcsec] FWHM of source k in x-di
# HIERARCH ESO QC EXPCOMB FWHM11 Y = 0.6357507 / [arcsec] FWHM of source k in y-di
# HIERARCH ESO QC EXPCOMB POS12 X = 334. / [pix] Position of source k in x-directi
# HIERARCH ESO QC EXPCOMB POS12 Y = 278. / [pix] Position of source k in y-directi
# HIERARCH ESO QC EXPCOMB FWHM12 X = 0.6903824 / [arcsec] FWHM of source k in x-di
# HIERARCH ESO QC EXPCOMB FWHM12 Y = 0.7592751 / [arcsec] FWHM of source k in y-di
# HIERARCH ESO QC EXPCOMB POS13 X = 333. / [pix] Position of source k in x-directi
# HIERARCH ESO QC EXPCOMB POS13 Y = 323. / [pix] Position of source k in y-directi
# HIERARCH ESO QC EXPCOMB FWHM13 X = 0.6412524 / [arcsec] FWHM of source k in x-di
# HIERARCH ESO QC EXPCOMB FWHM13 Y = 0.8296649 / [arcsec] FWHM of source k in y-di
# HIERARCH ESO QC EXPCOMB POS14 X = 243. / [pix] Position of source k in x-directi
# HIERARCH ESO QC EXPCOMB POS14 Y = 337. / [pix] Position of source k in y-directi
# HIERARCH ESO QC EXPCOMB FWHM14 X = 0.6785493 / [arcsec] FWHM of source k in x-di
# HIERARCH ESO QC EXPCOMB FWHM14 Y = 0.6344206 / [arcsec] FWHM of source k in y-di
# HIERARCH ESO QC EXPCOMB FWHM NVALID = 14 / Number of detected sources with valid
# HIERARCH ESO QC EXPCOMB FWHM MEDIAN = 0.6698691 / [arcsec] Median FWHM of all so
# HIERARCH ESO QC EXPCOMB FWHM MAD = 0.02145256 / [arcsec] Median absolute deviati
# HIERARCH ESO DRS MUSE OFFSET1 DRA = 0. / [deg] (= 0.000000 arcsec) RA offset app
# HIERARCH ESO DRS MUSE OFFSET1 DDEC = 0. / [deg] (= 0.000000 arcsec) DEC offset a
# HIERARCH ESO DRS MUSE FLUX SCALE1 = 0.999984829348428 / flux scale factor applie
# HIERARCH ESO DRS MUSE OFFSET1 DATE-OBS = '2017-07-02T00:23:05.000' / offset 1 ap
# HIERARCH ESO DRS MUSE OFFSET2 DRA = 9.16909894361929E-06 / [deg] (= 0.033009 arc
# HIERARCH ESO DRS MUSE OFFSET2 DDEC = 4.2621669577228E-07 / [deg] (= 0.001534 arc
# HIERARCH ESO DRS MUSE FLUX SCALE2 = 0.962962272675004 / flux scale factor applie
# HIERARCH ESO DRS MUSE OFFSET2 DATE-OBS = '2017-07-02T00:49:42.000' / offset 2 ap
# HIERARCH ESO DRS MUSE OFFSET3 DRA = 2.54294504111706E-05 / [deg] (= 0.091546 arc
# HIERARCH ESO DRS MUSE OFFSET3 DDEC = 0.000115507602609933 / [deg] (= 0.415827 ar
# HIERARCH ESO DRS MUSE FLUX SCALE3 = 0.999197912661188 / flux scale factor applie
# HIERARCH ESO DRS MUSE OFFSET3 DATE-OBS = '2017-07-02T01:23:02.000' / offset 3 ap
# HIERARCH ESO DRS MUSE OFFSET4 DRA = 4.61637837928147E-05 / [deg] (= 0.166190 arc
# HIERARCH ESO DRS MUSE OFFSET4 DDEC = 0.000105552003687926 / [deg] (= 0.379987 ar
# HIERARCH ESO DRS MUSE FLUX SCALE4 = 0.920120491593739 / flux scale factor applie
# HIERARCH ESO DRS MUSE OFFSET4 DATE-OBS = '2017-07-02T01:49:39.000' / offset 4 ap
# HIERARCH ESO DRS MUSE OFFSET5 DRA = 0.000127413921107376 / [deg] (= 0.458690 arc
# HIERARCH ESO DRS MUSE OFFSET5 DDEC = 8.84082995941181E-05 / [deg] (= 0.318270 ar
# HIERARCH ESO DRS MUSE FLUX SCALE5 = 0.994782830810715 / flux scale factor applie
# HIERARCH ESO DRS MUSE OFFSET5 DATE-OBS = '2017-07-02T02:21:43.000' / offset 5 ap
# HIERARCH ESO DRS MUSE OFFSET6 DRA = 0.000103191998960867 / [deg] (= 0.371491 arc
# HIERARCH ESO DRS MUSE OFFSET6 DDEC = 2.42734553131591E-05 / [deg] (= 0.087384 ar
# HIERARCH ESO DRS MUSE FLUX SCALE6 = 1.01660918312679 / flux scale factor applied
# HIERARCH ESO DRS MUSE OFFSET6 DATE-OBS = '2017-07-02T02:48:20.000' / offset 6 ap
# HIERARCH ESO DRS MUSE OFFSET7 DRA = -1.09175471532862E-05 / [deg] (= -0.039303 a
# HIERARCH ESO DRS MUSE OFFSET7 DDEC = 5.35686779716981E-05 / [deg] (= 0.192847 ar
# HIERARCH ESO DRS MUSE FLUX SCALE7 = 0.974951491046888 / flux scale factor applie
# HIERARCH ESO DRS MUSE OFFSET7 DATE-OBS = '2017-07-02T03:20:10.000' / offset 7 ap
# HIERARCH ESO DRS MUSE OFFSET8 DRA = 2.93640086246064E-05 / [deg] (= 0.105710 arc
# HIERARCH ESO DRS MUSE OFFSET8 DDEC = 1.32226000586957E-05 / [deg] (= 0.047601 ar
# HIERARCH ESO DRS MUSE FLUX SCALE8 = 0.982670010064429 / flux scale factor applie
# HIERARCH ESO DRS MUSE OFFSET8 DATE-OBS = '2017-07-02T03:46:47.000' / offset 8 ap
# HIERARCH ESO DRS MUSE FLUX FFCORR = T / Data was flat-field spectrum corrected
# CHECKSUM= 'MCn6PAk4MAk4MAk4'   / HDU checksum updated 2019-02-20T13:27:28
# DATASUM = '0       '           / data unit checksum updated 2019-02-20T13:27:28
# EBV     = '0.14200546699989292'

# %% [markdown]
# ## Cube Collapsing

# %% [markdown]
# Here we can collapse along a range of wavelength values, which is our z-axis, to produce a flattened section of the cube. Below are operations to collapse the first 300 wavelengths and display the 2D image.

# %%
collapsed_300D, collapsed_300S = manip.collapse_container(test_cube, 0, 300)

# %%
np.shape(collapsed_300D)
# Out:
# (353, 374)

# %%
plt.imshow(collapsed_300D, origin = 'lower')
plt.colorbar()

# %% [markdown]
# Alternatively, we could not specify a range and the function will collapse the entire container.

# %%
collapsed_fullD, collapsed_fullS = manip.collapse_container(test_cube)
# Out:
# collapse_container: Exceeded / unspecified wavelength in data cube. Max value is set to 1481
# collapse_container: Invalid / unspecified minimum wavelength. Min value is set to 0

# %%
np.shape(collapsed_fullD)
# Out:
# (353, 374)

# %%
plt.imshow(collapsed_fullD, origin = 'lower')
plt.colorbar()
gc.collect()
# Out:
# 30

# %% [markdown]
# ## De-reddening

# %% [markdown]
# There is an added function to correct for de-reddening of the data from cosmic dust. This function converts the entire data container which can then be re-collapsed and analyzed. Our code currently uses the extinction package with a model of Fitzpatrick & Massa (2007)

# %%
deRed_fullD, deRed_fullS = manip.dust_correction(test_cube)

# %%
deRed_collapse = manip.collapse_cube(deRed_fullD)
# Out:
# collapse_cube : Exceeded / unspecified wavelength in data cube. Max value is set to 1481
# collapse_cube : Invalid / unspecified minimum wavelength. Min value is set to 0

# %%
np.shape(deRed_collapse)
# Out:
# (353, 374)

# %%
plt.imshow(deRed_collapse, origin = 'lower')
plt.colorbar()

gc.collect()
# Out:
# 5614

# %% [markdown]
# # Background and Sources

# %% [markdown]
# ## Background Sub

# %% [markdown]
# First we want to remove any residual sources in the background.

# %% [markdown]
# subtract_bg is a function which utilizes SEP to smooth the background after isolating the sources. SEP is a re-creation of SourceXtractor for Python. These functions and beyond have parameters that must be tuned for each data set. We read in our object for some functions, where as others require output from earlier functions.

# %%
dataBg, statBg,_,_,_,_,_,_  = psf.subtract_bg(test_cube,
                                              sig_source_detect = 0.05,
                                              min_source_area=2.,
                                              source_mask_size=7.,
                                              edges=60,
                                              output = DATA_DIR,
                                              debug = True,
                                              show_debug = True,
                                              sigma_clipping = False)
gc.collect()
gc.collect()
# Out:
# subtract_bg: Starting the procedure to subtract the background
# stat_bg: Starting estimate of b/g stats
# collapse_cube : Exceeded / unspecified wavelength in data cube. Max value is set to 1481
# collapse_cube : Invalid / unspecified minimum wavelength. Min value is set to 0
# stat_bg: Searching for sources in the collapsed cube
# collapse_container: Exceeded / unspecified wavelength in data cube. Max value is set to 1481
# collapse_container: Invalid / unspecified minimum wavelength. Min value is set to 0
# stat_bg: Detected 44 sources
# stat_bg: Masking Edges
# stat_bg: Masking sources
# stat_bg: Performing b/g statistic
# stat_bg: Saving debug image on /home/ryan.foley/Downloads/P231COPY.fits_BgRegion.pdf
# subtract_bg: Subtracting background from datacube
# subtract_bg: Estimating correction for statcube variance
# subtract_bg: The average correction factor for variance is 0.99945
# nice_plot: Setting rcParams
# subtract_bg: The average value subtracted to the b/g level is 0.03503
# nice_plot: Setting rcParams
# 0

# %%
averageBg, medianBg, stdBg, varBg, pixelsBg, maskBg2D = psf.stat_bg(test_cube,
                                                                    sig_source_detect=0.05,
                                                                    min_source_area=2.,
                                                                    source_mask_size=7.,
                                                                    edges=60,
                                                                    output = DATA_DIR,
                                                                    debug = True,
                                                                    show_debug = True)
gc.collect()
gc.collect()
# Out:
# stat_bg: Starting estimate of b/g stats
# collapse_cube : Exceeded / unspecified wavelength in data cube. Max value is set to 1481
# collapse_cube : Invalid / unspecified minimum wavelength. Min value is set to 0
# stat_bg: Searching for sources in the collapsed cube
# collapse_container: Exceeded / unspecified wavelength in data cube. Max value is set to 1481
# collapse_container: Invalid / unspecified minimum wavelength. Min value is set to 0
# stat_bg: Detected 44 sources
# stat_bg: Masking Edges
# stat_bg: Masking sources
# stat_bg: Performing b/g statistic
# stat_bg: Saving debug image on /home/ryan.foley/Downloads/P231COPY.fits_BgRegion.pdf
# 0

# %% [markdown]
# ## Writing to File

# %% [markdown]
# Here we have a function which performs the above tasks of background isolation and source masking. It iterates through the entire cube, and writes the background and masks to the file. These code blocks are not active but are here to represent the availability of this function with the package.

# %% [raw]
# test_cube.get_background()

# %% [raw]
# test_cube.hdul.writeto('writetotest.fits',output_verify = 'silentfix', overwrite = True,checksum = True)

# %% [raw]
# test_cube.hdul.info()

# %% [markdown]
# Below it shows the now updated .fits with added rows for 'MASK' and 'BACKGROUND'.

# %% [markdown]
# We can showcase an example of the new sections by slicing a single wavelength and plotting the image.

# %% [raw]
# plt.imshow(test_cube.hdul[4].data[120,:,:], origin = 'lower')
# plt.title('Example of BACKGROUND',size = 18)
# plt.colorbar()

# %% [raw]
# plt.imshow(test_cube.hdul[3].data[120,:,:], origin = 'lower')
# plt.title('Example of MASK', size = 18)
# plt.colorbar()

# %% [markdown]
# # Wavelengths

# %% [markdown]
# ## Atmosphere

# %% [markdown]
# We can also convert our channel values into wave lengths using the 'convert_to_wave' function from the manip module.
# This function is utilized in other functions as well, but it stands on it's own for usability.

# %%
wavearray = manip.convert_to_wave(test_cube,test_cube.get_data())

# %% [markdown]
# Ploting the subtracted background average, median and sigma with the wave lengths yields the plot below. Notice that sigma is our atmospheric background.

# %%
plt.figure(0, figsize=(16,6))
plt.plot(wavearray, averageBg, alpha=0.7, color='dodgerblue', label='b/g average')
plt.plot(wavearray, stdBg, alpha=0.7, color='grey', label='b/g $\sigma$')
plt.plot(wavearray, medianBg, alpha=0.7, color='crimson', label='b/g median')
plt.xlabel(r'Wavelength [$\AA$]')
plt.ylabel(r'Flux [10$^{-17}$erg/s/cm$^2$/$\AA$]')
plt.legend(prop={"size": 15})
plt.title('Atmospheric Spectra P231m20')

gc.collect()
# Out:
# 30

# %% [markdown]
# ## Quasar Spectrum

# %% [markdown]
# Using the function 'q_spectrum' from the manip module, we can extract the spectra from the object of interest. This function assumes the RA and DEC of the object have been converted to pixel values.

# %%
fluxQso, errQso, bgQso = manip.q_spectrum(test_cube,x_pos,y_pos)

# %% [markdown]
# We can plot the the data wavelengths against this flux

# %%
plt.figure(0, figsize=(16,6))
plt.plot(wavearray,fluxQso, alpha = 0.7, color = 'grey', label = "Flux")
plt.plot(wavearray,errQso,alpha = 0.7, color = 'dodgerblue', label = "$\sigma$")
plt.plot(wavearray,bgQso,alpha = 0.7, color = 'crimson', label = "Bg")
plt.xlabel(r'Wavelength [$\AA$]')
plt.ylabel(r'Flux [10$^{-17}$erg/s/cm$^2$/$\AA$]')
plt.title('Object P231m20 Spectra')
plt.legend(prop={'size': 15})

# %% [markdown]
# ------------------

# %% [markdown]
# Another helpful function is to call .get_dimensions on the IFUcube object to quickly get its value ranges. Specifically, this is helpful to see the channel ranges of the previous plot.

# %%
z_max, y_max, x_max = test_cube.get_dimensions()
channelarray = np.arange(0,z_max, 1)

# %%
plt.figure(0, figsize=(16,6))
plt.plot(channelarray,fluxQso, alpha = 0.7, color = 'grey', label = "Flux")
plt.plot(channelarray,errQso,alpha = 0.7, color = 'dodgerblue', label = "$\sigma$")
plt.plot(channelarray,bgQso,alpha = 0.7, color = 'crimson', label = "Bg")
plt.xlabel(r'Channel # (z)')
plt.ylabel(r'Flux [10$^{-17}$erg/s/cm$^2$/$\AA$]')
plt.title('Object P231m20 Spectra')
plt.legend(prop={'size': 15})

gc.collect()
# Out:
# 9026

# %% [markdown]
#  From this plot, we can easily visualize the channel values where we need to cut off / shrink the cube to perform the following functions in the package.

# %% [markdown]
#  ----------------

# %% [markdown]
# # Point Spread Function

# %% [markdown]
# The following code impliments a point-spread function to remove the highly luminous QSO (or other source) to isolate the potential surround halo.

# %% [markdown]
# ## PSF Creation

# %% [markdown]
# The first step is to normalize the flux produced by the QSO. using c_type=sum does just this. We also need to perform this function along the continuum just beyond were we estimate our LYa emission to be.

# %%
    psf_data, psf_stat = psf.create_psf(dataBg,statcube=statBg,x_pos=x_pos,y_pos=y_pos,
                                    inner_rad=20,outer_rad=30,
                                    min_lambda=1400,max_lambda=1430,
                                    debug = True,show_debug=True, c_type = 'sum')
gc.collect()
gc.collect()
# Out:
# create_psf: Creating PSF model
# create_psf: Summing channels
# quick_ap_photometry: Performing aperture photometry
# Source 1 : Aperture photometry on source at: 189.87105600022025, 155.2889880000135
# create_psf: Removing local background of [2.19820392]
# create_psf: Normalizing central region to 1
#          (i.e. correcting for a factor [25484.76915497]
# create_psf: Creating circular mask around the position 189.87105600022025, 155.2889880000135
# location: single source identified
# create_psf: Creating debug images
# nice_plot: Setting rcParams
# 0

# %% [markdown]
# -------------

# %% [markdown]
# ## PSF Cleaning

# %% [markdown]
# The function 'clean_psf' from the fitting psf module takes the now normalized psf model and subtracts the contribution.

# %%
dataCubeClean, dataCubeModel = psf.clean_psf(test_cube,
                                             psf_model=psf_data,
                                             x_pos=x_pos,y_pos=y_pos,
                                             debug=True,radius_pos=2.,
                                             inner_rad=15.,outer_rad = 25.,
                                             show_debug = True) 
gc.collect()
gc.collect()
# Out:
# clean_psf: PSF subtraction on cube
# clean_psf: The min, max values for PSF model are: -0.0046, 0.1563
# clean_psf: Spectrum of the source
# nice_plot: Setting rcParams
# clean_psf: PSF cleaning performed
# 0

# %% [markdown]
# # Halo Finding

# %% [markdown]
# To preserve memory and remain accurate, we use two parameters here to smooth our data. These are the background corrected data and variance cubes. The function 'smooth_chicube' smooths the cube in the spatial (a_smooth) and spectral (v_smooth) axes.
#
# We use the above plots to set our shrinking parameters min and max lambda.

# %% [markdown]
# ## Cube Smoothing

# %%
chiCube, sChiCube = halos.smooth_chicube(dataCubeClean,statcube=statBg,
                                         min_lambda=1350,
                                         max_lambda=1390,
                                         a_smooth=1,
                                         v_smooth=2)
np.shape(sChiCube)
# Out:
# smooth_chicube: Shrinking cube with given parameters
# smooth_chicube: Smoothing cube with 3D Gaussian Kernel
# (40, 353, 374)

# %% [markdown]
# ----------------

# %% [markdown]
# ## Halo Mask

# %% [markdown]
# halo_mask is the crucial function to the halo finding module. This function performs a friend of friend algorith from a high value voxel nearby the source on the now smoothed and background corrected cube.

# %%
maskHalo = halos.halo_mask(sChiCube,
                           x_pos=x_pos,
                           y_pos=y_pos,
                           z_pos=25,
                           rad_bad_pix=1,
                           rad_max=40,
                           r_connect=2,
                           threshold=2,
                           threshold_type='relative',
                           bad_pixel_mask=None,
                           output=DATA_DIR,
                           debug=True,
                           show_debug=True)
gc.collect()
gc.collect()
# Out:
# halo_mask: removing inner region around (x,y)=(189.87,155.29)
#           with radius 1 pixels
# location: single source identified
# halo_mask: removing outer region around (x,y)=(189.87,155.29)
#           with radius 40 pixels
# location: single source identified
# halo_mask: defining threshold level
# stat_fullcube: statistic on the cube
# stat_fullcube: average = +0.047
#               median  = +0.045
#               sigma   = +0.188
# stat_fullcube_z: statistic on the cube
# halo_mask: the median value of the voxels is: +0.0452
#           and the sigma is: +0.1883
# halo_mask: the average relative threshold value set to 2.00*0.1883=0.3766
# halo_mask: Saving debug image on /home/ryan.foley/Downloads/P231COPY.fits_voxelDistribution.pdf
#           in principle the distribution should be gaussian
#           showing only channel 20
# nice_plot: Setting rcParams
# halo_mask: searching for extended emission
#           starting from from (x,y,z)=(189.87,155.289,25)
# halo_mask: the maximum S/N detected is 0.673
#           at the location (x,y,z)=(186,157,27)
# halo_mask: starting to fill the halo mask
# halo_mask: Creating debug image
#           Plotting Channel 27 where the most significant voxel is.
#           The location of this voxel is marked with a red circle
#           The position of the quasar is in blue
# nice_plot: Setting rcParams
# spectral_mask_halo: collapsing halo mask
# halo_mask: debug image saved in /home/ryan.foley/Downloads/P231COPY.fits_maskHaloStartingVoxel.pdf
# 0
